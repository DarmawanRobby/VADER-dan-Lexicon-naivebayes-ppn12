# %%
# !pip install openpyxl pyspellchecker
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.2-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Downloading pyspellchecker-0.8.2-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 39.9 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.2

# %%
import pandas as pd
from spellchecker import SpellChecker
from IPython.display import display

# Replace 'your_file.xlsx' with the actual name of your uploaded file
file_path = 'Komentar Najwa Sihab.xlsx'
df = pd.read_excel(file_path)
display(df)
# Out:
#                                                comments           username
# 0     Pak tolong PPN pajaknya di turunin soalnya say...          sofwati79
# 1              Smg sehat dan panjang umur pak presiden🔥    hidayatulummah3
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...          wnddesign
# 3                                                Masa 🫣     strarawberries
# 4                                       la nggeh ngoten         damara.day
# ...                                                 ...                ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...         duni4_may4
# 1630  Barang mewah adalah ………. \nYang termasuk baran...          wigiyantz
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...  mhd_rihilmiski493
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...          adputra99
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...      yandaekaputra
#
# [1634 rows x 2 columns]

# %% [markdown]
# Normalisasi (Spelling) & Case Folding (LowerCase)

# %%
import pandas as pd
import re

# Load data from Excel
file_path = "Komentar Najwa Sihab.xlsx"  # Ubah dengan lokasi file Anda
data = pd.read_excel(file_path)

# Define spelling correction dictionary
spelling_corrections = {
    r'\budh\b': 'sudah',
    r'\bkrn\b': 'karena',
    r'\bdlm\b': 'dalam',
    r'\bdpt\b': 'dapat',
    r'\byg\b': 'yang',
    r'\bklo\b': 'kalau',
    r'\btrsedia\b': 'tersedia',
    r'\btrsdia\b': 'tersedia',
    r'\btersdia\b': 'tersedia',
    r'\btdk\b': 'tidak',
    r'\bsmg\b': 'semoga',
    r'\btlg\b': 'tolong'
}

# Function to correct spelling
def correct_spelling(comment):
    comment = str(comment).lower()
    for pattern, replacement in spelling_corrections.items():
        comment = re.sub(pattern, replacement, comment)
    return comment

# Apply spelling correction
data["Corrected_Comments"] = data["comments"].apply(correct_spelling)

# Display the resulting table
display(data[["comments", "Corrected_Comments"]])
# Out:
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
# [1634 rows x 2 columns]

# %% [markdown]
# Tokenizing

# %%
import pandas as pd
from spellchecker import SpellChecker
from IPython.display import display
import re

# Assuming 'data' DataFrame is already loaded as in the previous code

# Tokenization function
def tokenize(text):
    text = re.sub(r'[^\w\s]', '', str(text)) # Remove punctuation
    tokens = text.lower().split()
    return tokens

# Apply tokenization
data['tokens'] = data['Corrected_Comments'].apply(tokenize)

# Display the DataFrame with tokens
display(data[['comments', 'Corrected_Comments', 'tokens']])
# Out:
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments  \
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
#                                                  tokens
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                [masa]
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, yang, yang, ...
# 1630  [barang, mewah, adalah, yang, termasuk, barang...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, yang, disasar, orang, kaya, ka...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
# [1634 rows x 3 columns]

# %% [markdown]
# Filtering

# %%
# Assuming 'data' DataFrame is already loaded and processed as in the previous code

# Example filtering: Remove comments containing specific words
stop_words = ['kata', 'yang', 'tidak', 'ini']  # Add your stop words here

def filter_comments(tokens):
    return [word for word in tokens if word not in stop_words]

data['filtered_tokens'] = data['tokens'].apply(filter_comments)

# Display the DataFrame with filtered tokens
display(data[['comments', 'Corrected_Comments', 'tokens', 'filtered_tokens']])


# Further filtering example: Remove comments shorter than a certain length
min_length = 3  # Minimum number of tokens

def filter_by_length(tokens):
  return tokens if len(tokens) >= min_length else []

data['filtered_tokens_length'] = data['filtered_tokens'].apply(filter_by_length)
display(data[['comments', 'Corrected_Comments', 'tokens', 'filtered_tokens', 'filtered_tokens_length']])

columns_to_download = ['comments', 'Corrected_Comments', 'filtered_tokens_length']
# You can modify this list to include other relevant columns

# Create a new DataFrame with the selected columns
filtered_data_to_download = data[columns_to_download]

# Save the DataFrame to an XLSX file
filtered_data_to_download.to_excel('filtered_comments.xlsx', index=False)

print("Filtered data downloaded to filtered_comments.xlsx")
# Out:
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments  \
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
#                                                  tokens  \
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                [masa]
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, yang, yang, ...
# 1630  [barang, mewah, adalah, yang, termasuk, barang...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, yang, disasar, orang, kaya, ka...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
#                                         filtered_tokens
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                [masa]
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, kena, pajak,...
# 1630  [barang, mewah, adalah, termasuk, barang, mewa...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, disasar, orang, kaya, karena, ...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
# [1634 rows x 4 columns]
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments  \
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
#                                                  tokens  \
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                [masa]
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, yang, yang, ...
# 1630  [barang, mewah, adalah, yang, termasuk, barang...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, yang, disasar, orang, kaya, ka...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
#                                         filtered_tokens  \
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                [masa]
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, kena, pajak,...
# 1630  [barang, mewah, adalah, termasuk, barang, mewa...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, disasar, orang, kaya, karena, ...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
#                                  filtered_tokens_length
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...
# 3                                                    []
# 4                                   [la, nggeh, ngoten]
# ...                                                 ...
# 1629  [usaha, rike, di, tangapi, dasco, kena, pajak,...
# 1630  [barang, mewah, adalah, termasuk, barang, mewa...
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...
# 1632  [semoga, benar, disasar, orang, kaya, karena, ...
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...
#
# [1634 rows x 5 columns]
# Filtered data downloaded to filtered_comments.xlsx

# %% [markdown]
# Jumlah Komentar
# Sentimen Positif dan negatif dari !wget https://raw.githubusercontent.com/fajri91/InSet/master/negative.tsv
# !wget https://raw.githubusercontent.com/fajri91/InSet/master/positive.tsv
# scoring terbanyak itu adalah hasil sentimen

# %%
import pandas as pd

# Load the positive and negative word lists
positive_words = pd.read_csv('positive.tsv', sep='\t', header=None)[0].tolist()
negative_words = pd.read_csv('negative.tsv', sep='\t', header=None)[0].tolist()

def calculate_sentiment_score(tokens):
    positive_score = 0
    negative_score = 0
    for token in tokens:
        if token in positive_words:
            positive_score += 1
        elif token in negative_words:
            negative_score += 1
    return positive_score, negative_score

def classify_sentiment(positive_score, negative_score):
    if positive_score > negative_score:
        return "Positif"
    elif negative_score > positive_score:
        return "Negatif"
    else:
        return "Netral"

# Assuming 'data' DataFrame is already loaded and processed
data['positive_score'], data['negative_score'] = zip(*data['filtered_tokens_length'].apply(calculate_sentiment_score))
data['sentiment'] = data.apply(lambda row: classify_sentiment(row['positive_score'], row['negative_score']), axis=1)

sentiment_counts = data['sentiment'].value_counts()

# Print the counts
print("Sentiment Counts:")
print(sentiment_counts)
# Display the DataFrame with sentiment analysis results
display(data[['comments', 'Corrected_Comments', 'filtered_tokens_length', 'positive_score', 'negative_score', 'sentiment']])


# Save the results to a new Excel file
data.to_excel('sentiment_analysis_results.xlsx', index=False)
print("Sentiment analysis results saved to sentiment_analysis_results.xlsx")
# Out:
# Sentiment Counts:
# sentiment
# Positif    629
# Netral     598
# Negatif    407
# Name: count, dtype: int64
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments  \
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
#                                  filtered_tokens_length  positive_score  \
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...               7
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...               4
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...               0
# 3                                                    []               0
# 4                                   [la, nggeh, ngoten]               0
# ...                                                 ...             ...
# 1629  [usaha, rike, di, tangapi, dasco, kena, pajak,...               1
# 1630  [barang, mewah, adalah, termasuk, barang, mewa...               1
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...               4
# 1632  [semoga, benar, disasar, orang, kaya, karena, ...               3
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...               5
#
#       negative_score sentiment
# 0                  5   Positif
# 1                  0   Positif
# 2                  2   Negatif
# 3                  0    Netral
# 4                  0    Netral
# ...              ...       ...
# 1629               2   Negatif
# 1630               2   Negatif
# 1631               1   Positif
# 1632               1   Positif
# 1633               6   Negatif
#
# [1634 rows x 6 columns]
# Sentiment analysis results saved to sentiment_analysis_results.xlsx

# %% [markdown]
# sentimen analys menggunakan VADAR

# %%
# Install VADER lexicon
# !pip install vaderSentiment

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

def analyze_sentiment_vader(text):
    scores = analyzer.polarity_scores(text)
    compound_score = scores['compound']
    if compound_score >= 0.05:
        return "Positif"
    elif compound_score <= -0.05:
        return "Negatif"
    else:
        return "Netral"

# Apply VADER sentiment analysis to the 'Corrected_Comments' column
data['vader_sentiment'] = data['Corrected_Comments'].apply(analyze_sentiment_vader)

# Display the DataFrame with VADER sentiment analysis results
display(data[['comments', 'Corrected_Comments', 'filtered_tokens_length', 'positive_score', 'negative_score', 'sentiment', 'vader_sentiment']])

# Save the results to a new Excel file
data.to_excel('sentiment_analysis_results_vader.xlsx', index=False)
print("Sentiment analysis results (VADER) saved to sentiment_analysis_results_vader.xlsx")

vader_sentiment_counts = data['vader_sentiment'].value_counts()
print("\nVADER Sentiment Counts:")
vader_sentiment_counts
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2024.12.14)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
#                                                comments  \
# 0     Pak tolong PPN pajaknya di turunin soalnya say...
# 1              Smg sehat dan panjang umur pak presiden🔥
# 2     Barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                Masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  Usaha rike di tangapi dasco  yg yg kena pajak ...
# 1630  Barang mewah adalah ………. \nYang termasuk baran...
# 1631  Lebih ke kendaraan mungkin kalo hp sudah ada P...
# 1632  Semoga benar yg disasar orang kaya, krn pasti ...
# 1633  Barang 10 juta ke atas wajib sih pak , minimal...
#
#                                      Corrected_Comments  \
# 0     pak tolong ppn pajaknya di turunin soalnya say...
# 1           semoga sehat dan panjang umur pak presiden🔥
# 2     barng mewah untuk kalangan apa pak 😢 apakah ka...
# 3                                                masa 🫣
# 4                                       la nggeh ngoten
# ...                                                 ...
# 1629  usaha rike di tangapi dasco  yang yang kena pa...
# 1630  barang mewah adalah ………. \nyang termasuk baran...
# 1631  lebih ke kendaraan mungkin kalo hp sudah ada p...
# 1632  semoga benar yang disasar orang kaya, karena p...
# 1633  barang 10 juta ke atas wajib sih pak , minimal...
#
#                                  filtered_tokens_length  positive_score  \
# 0     [pak, tolong, ppn, pajaknya, di, turunin, soal...               7
# 1     [semoga, sehat, dan, panjang, umur, pak, presi...               4
# 2     [barng, mewah, untuk, kalangan, apa, pak, apak...               0
# 3                                                    []               0
# 4                                   [la, nggeh, ngoten]               0
# ...                                                 ...             ...
# 1629  [usaha, rike, di, tangapi, dasco, kena, pajak,...               1
# 1630  [barang, mewah, adalah, termasuk, barang, mewa...               1
# 1631  [lebih, ke, kendaraan, mungkin, kalo, hp, suda...               4
# 1632  [semoga, benar, disasar, orang, kaya, karena, ...               3
# 1633  [barang, 10, juta, ke, atas, wajib, sih, pak, ...               5
#
#       negative_score sentiment vader_sentiment
# 0                  5   Positif          Netral
# 1                  0   Positif         Negatif
# 2                  2   Negatif         Negatif
# 3                  0    Netral          Netral
# 4                  0    Netral          Netral
# ...              ...       ...             ...
# 1629               2   Negatif          Netral
# 1630               2   Negatif          Netral
# 1631               1   Positif          Netral
# 1632               1   Positif          Netral
# 1633               6   Negatif         Negatif
#
# [1634 rows x 7 columns]
# Sentiment analysis results (VADER) saved to sentiment_analysis_results_vader.xlsx
#
# VADER Sentiment Counts:
# vader_sentiment
# Netral     1142
# Positif     319
# Negatif     173
# Name: count, dtype: int64

# %% [markdown]
# Visualisasi

# %%
_df_0 = data

# Now you can plot the histogram for 'positive_score'
_df_0['positive_score'].plot(kind='hist', bins=20, title='positive_score')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# Similarly, assign 'data' to '_df_1' for the 'negative_score' plot
_df_1 = data

_df_1['negative_score'].plot(kind='hist', bins=20, title='negative_score')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
from matplotlib import pyplot as plt

# Visualisasi positive_score
plt.figure(figsize=(8, 4))  # Membuat figure baru untuk positive_score
# Replace '_df_4' with 'data' to use the original DataFrame
plt.plot(data['positive_score'], label='Positive Score')
plt.title('Positive Score Trend')
plt.xlabel('Index')  # Ganti dengan label yang sesuai untuk sumbu x
plt.ylabel('Positive Score')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.legend()
plt.show()

# Visualisasi negative_score
plt.figure(figsize=(8, 4))  # Membuat figure baru untuk negative_score
# Replace '_df_5' with 'data' to use the original DataFrame
plt.plot(data['negative_score'], label='Negative Score', color='red')
plt.title('Negative Score Trend')
plt.xlabel('Index')  # Ganti dengan label yang sesuai untuk sumbu x
plt.ylabel('Negative Score')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Replace '_df_2' with 'data'
data.groupby('sentiment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Visualisasi wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming 'data' DataFrame and 'filtered_tokens_length' column exist as in the previous code

# Combine all filtered tokens into a single string
all_tokens = ' '.join([' '.join(tokens) for tokens in data['filtered_tokens_length']])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_tokens)

# Display the generated image:
plt.figure(figsize=(10, 5), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# Frekuensi kemunculan kata TF-IDF

# %%
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

# Instead of loading a new DataFrame, use the existing 'data' DataFrame
# which already contains the 'filtered_tokens_length' column
# data = pd.read_excel("Komentar Najwa Sihab.xlsx") # This line is removed

# Ensure that the code to create 'filtered_tokens_length' has been executed before this cell
# If not, you can include the relevant code snippets here or make sure the previous cells are executed in order.
# For example, if the column was created in a previous cell with the following code:
#
# data['tokens'] = data['Corrected_Comments'].apply(tokenize)
# data['filtered_tokens'] = data['tokens'].apply(filter_comments)
# data['filtered_tokens_length'] = data['filtered_tokens'].apply(filter_by_length)
#
# Then you need to make sure that cell is executed before this one.

def word_frequency(tokens_list):
    """
    Calculates the frequency of words in a list of token lists.

    Args:
        tokens_list: A list where each element is a list of tokens (strings).

    Returns:
        A Counter object representing word frequencies.
    """
    all_tokens = [token for sublist in tokens_list for token in sublist]
    word_counts = Counter(all_tokens)
    return word_counts

# Example usage (assuming 'data' and 'filtered_tokens_length' are defined as in your code):
# If 'filtered_tokens_length' column is still missing, re-create it here:
if 'filtered_tokens_length' not in data.columns:
    # Include the necessary functions and code to create this column
    # Example (assuming you have the functions defined elsewhere):
    def tokenize(text):
        text = re.sub(r'[^\w\s]', '', str(text))  # Remove punctuation
        tokens = text.lower().split()
        return tokens

    def filter_comments(tokens):
        stop_words = ['kata', 'yang', 'tidak', 'ini']  # Add your stop words here
        return [word for word in tokens if word not in stop_words]

    def filter_by_length(tokens):
        min_length = 3  # Minimum number of tokens
        return tokens if len(tokens) >= min_length else []

    # Apply the functions to create the column
    data['tokens'] = data['Corrected_Comments'].apply(tokenize)
    data['filtered_tokens'] = data['tokens'].apply(filter_comments)
    data['filtered_tokens_length'] = data['filtered_tokens'].apply(filter_by_length)

word_counts = word_frequency(data['filtered_tokens_length'].tolist())

# Sort the word counts from highest to lowest frequency
sorted_word_counts = word_counts.most_common()

# Print the sorted word frequencies in a table-like format
print("Word\t\tFrequency\tTF-IDF")
print("----\t\t---------\t------")  # Separator line

# Calculate TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([' '.join(tokens) for tokens in data['filtered_tokens_length']])
feature_names = vectorizer.get_feature_names_out()

# Get TF-IDF values for each word
tfidf_values = {word: tfidf_matrix.sum(axis=0)[0, feature_names.tolist().index(word)]
                for word, _ in sorted_word_counts if word in feature_names.tolist()}

# Print word frequencies with TF-IDF
for word, count in sorted_word_counts:
    tfidf = tfidf_values.get(word, 0)  # Get TF-IDF, default to 0 if not found
    print(f"{word:<15}\t{count}\t\t{tfidf:.4f}")
# Out:
# Word		Frequency	TF-IDF
# ----		---------	------
# barang         	459		64.4959
# mewah          	456		64.4644
# pak            	333		56.0129
# di             	273		33.7249
# ppn            	202		33.1372
# apa            	165		35.4293
# itu            	163		27.7143
# dan            	153		18.6357
# ada            	145		23.6540
# pajak          	143		22.4309
# ya             	140		28.8972
# rakyat         	135		23.2739
# aja            	132		25.3533
# nya            	130		20.6109
# naik           	113		23.3508
# ppnbm          	106		25.6868
# untuk          	104		15.6359
# presiden       	104		21.6444
# 12             	101		17.4553
# gak            	95		20.0029
# kalau          	94		16.2568
# bisa           	91		15.3361
# kena           	89		17.5797
# ga             	86		17.2244
# ke             	85		14.9165
# kalo           	84		16.8619
# juga           	83		15.3842
# kan            	79		15.4638
# saya           	78		13.6390
# seperti        	71		12.0353
# beli           	68		12.8992
# dari           	66		11.5066
# jadi           	66		12.6151
# sudah          	65		12.4230
# sama           	62		13.7279
# atau           	61		9.5688
# buat           	58		10.3246
# bukan          	57		12.2443
# harga          	54		11.1491
# termasuk       	51		12.8386
# semoga         	50		13.3520
# prabowo        	50		12.4108
# kaya           	50		11.0279
# saja           	49		10.6287
# mobil          	48		10.2595
# udah           	48		11.2296
# orang          	47		10.7979
# tanya          	45		10.6362
# dengan         	45		7.2647
# semua          	45		8.5932
# lagi           	44		9.0146
# masih          	43		8.4135
# kecil          	43		9.3855
# jangan         	43		9.3505
# tapi           	43		8.6405
# kita           	42		9.3191
# tetap          	41		8.6571
# karena         	41		6.9966
# pasti          	41		8.7995
# rumah          	39		8.8380
# makan          	39		8.2618
# banyak         	39		7.5973
# jelas          	39		8.6513
# tau            	38		9.3273
# kendaraan      	38		6.3577
# lah            	37		9.3427
# bapak          	37		9.8822
# negara         	37		6.5544
# sih            	37		9.2067
# gaji           	36		8.3401
# punya          	36		8.0207
# nanti          	35		8.0584
# 11             	35		7.4670
# lebih          	34		7.2885
# motor          	33		6.9325
# biar           	33		6.1864
# mau            	33		7.4631
# baru           	32		6.9371
# kok            	32		8.3695
# hanya          	32		5.9795
# d              	32		0.0000
# dulu           	32		7.9136
# yaa            	29		6.7472
# gimana         	29		8.1987
# masuk          	29		8.6404
# pada           	28		5.8884
# akan           	27		5.1816
# 10             	27		6.6783
# atas           	27		6.8779
# dong           	26		8.7375
# gk             	26		6.3594
# bayar          	25		5.4555
# indonesia      	25		6.2600
# beda           	25		7.3054
# terus          	25		5.5209
# nih            	25		7.8626
# guru           	25		6.0785
# 1              	25		0.0000
# tuh            	24		7.1195
# sekarang       	24		5.6915
# jgn            	24		5.5698
# lu             	24		6.0538
# kami           	23		4.8512
# mana           	23		5.9590
# pemerintah     	23		4.4074
# belum          	23		4.0079
# tolong         	22		4.8198
# selalu         	22		5.6988
# kategori       	22		7.8697
# harus          	22		5.2905
# masyarakat     	21		3.8917
# mulyono        	21		6.5466
# hp             	21		5.4914
# coba           	21		4.8538
# nah            	21		6.3718
# berarti        	21		6.5307
# aku            	21		5.6399
# si             	21		5.5207
# menengah       	21		5.1241
# cuma           	21		4.8044
# mungkin        	21		5.1101
# tp             	20		4.6010
# 2              	20		0.0000
# tahun          	20		4.0972
# kebutuhan      	19		3.7304
# lain           	19		4.1845
# bilang         	19		4.3947
# gitu           	19		5.6044
# kerja          	19		2.7555
# jawab          	19		4.9410
# miskin         	18		4.2722
# salah          	18		4.3339
# pokok          	18		3.9818
# anak           	18		4.2640
# jd             	18		5.1953
# banget         	18		4.8162
# dalam          	18		3.6149
# dikenakan      	18		3.2271
# sendiri        	17		5.3170
# tetep          	17		4.8738
# ndak           	17		5.1849
# mewahnya       	17		5.6697
# bahan          	17		3.8501
# bukannya       	17		7.2104
# dll            	17		3.8815
# kasih          	17		4.5156
# sehat          	16		5.9385
# iphone         	16		5.3629
# contoh         	16		5.0454
# kemarin        	16		4.5926
# langsung       	16		4.1422
# agar           	16		3.1347
# mereka         	16		3.1297
# mulai          	16		3.8279
# bagi           	16		3.7481
# apakah         	15		3.7258
# org            	15		3.7594
# dr             	15		3.3709
# berapa         	15		4.9988
# para           	14		3.6329
# sdh            	14		3.8898
# naikin         	14		3.6422
# kenaikan       	14		4.0396
# baik           	14		3.6004
# iya            	14		4.7787
# nanya          	14		3.7115
# kali           	14		3.4261
# liat           	14		3.2780
# g              	14		0.0000
# mah            	13		3.9584
# lg             	13		2.9327
# biasa          	13		2.7838
# aturan         	13		2.7387
# uang           	13		2.1336
# pun            	13		3.0206
# ku             	13		4.4740
# 5              	13		0.0000
# sampai         	13		3.2739
# uu             	13		2.7409
# skrg           	13		2.7998
# ditanya        	13		3.2959
# udara          	13		2.1175
# alhamdulillah  	13		4.6861
# mohon          	13		1.8108
# harganya       	13		3.9809
# sya            	13		1.0973
# pajaknya       	12		3.7865
# roti           	12		2.9900
# jelata         	12		4.3067
# mahal          	12		2.8231
# definisi       	12		4.7297
# emang          	12		2.6282
# bakal          	12		2.4773
# suka           	12		4.3487
# bener          	12		3.6383
# makin          	12		2.9551
# diatas         	12		3.3350
# begitu         	12		3.9758
# dapat          	12		2.2613
# doang          	12		3.7351
# malah          	12		2.6860
# mampu          	12		3.5750
# padahal        	12		2.6203
# baca           	12		3.2099
# mending        	12		3.5640
# tarif          	12		2.3602
# berlaku        	12		2.4615
# kah            	12		4.5247
# usaha          	12		2.6605
# info           	12		2.5281
# omon           	12		3.7466
# jg             	12		3.0378
# minimal        	12		3.6823
# makanan        	11		2.5263
# 3              	11		0.0000
# tas            	11		3.1300
# 15             	11		3.4558
# bagaimana      	11		2.7956
# otak           	11		3.2977
# beliau         	11		2.1560
# penting        	11		3.1248
# paham          	11		2.9218
# mentri         	11		2.9496
# dpr            	11		2.9752
# 400k           	11		2.6014
# maksud         	11		2.5270
# pejabat        	11		2.7392
# persen         	11		2.2864
# soalnya        	10		1.7447
# umkm           	10		1.9069
# pengusaha      	10		2.2129
# blm            	10		1.7910
# utk            	10		2.1227
# sy             	10		2.1293
# barang2        	10		2.5669
# ttp            	10		2.7366
# sampe          	10		2.4784
# tanyakan       	10		2.4746
# dgn            	10		2.3652
# perlu          	10		2.3614
# tinggal        	10		2.5935
# jawabannya     	10		3.3613
# jelaskan       	10		3.2918
# gmn            	10		3.1233
# cari           	10		2.2537
# hal            	10		1.9547
# lihat          	10		3.2680
# terima         	10		2.8062
# lalu           	10		2.1222
# gw             	10		2.8960
# sembako        	10		2.7098
# aj             	10		3.1026
# besar          	10		1.9024
# paling         	10		2.8694
# luar           	10		2.3351
# pake           	10		2.9101
# pa             	10		3.1708
# namanya        	10		4.3526
# resto          	10		2.6071
# tu             	10		3.5755
# penjelasan     	10		2.6721
# beras          	10		3.2094
# ngambang       	10		3.0580
# kelompok       	10		0.8821
# bikin          	9		1.9659
# harusnya       	9		3.1984
# sebagai        	9		1.9260
# hidup          	9		1.5571
# setelah        	9		2.2174
# hasil          	9		2.0934
# korupsi        	9		1.5814
# jawaban        	9		2.8074
# tinggi         	9		1.6684
# kayak          	9		2.4710
# 4              	9		0.0000
# pesawat        	9		1.5500
# gede           	9		1.8913
# 2025           	9		1.8401
# akhir          	9		2.3978
# gini           	9		3.4153
# kalian         	9		2.5800
# yo             	9		2.7456
# lo             	9		2.5013
# komentar       	9		2.7723
# sesuai         	9		2.8293
# kebijakan      	9		2.0121
# kebawah        	9		2.3613
# ny             	9		2.3134
# menyala        	9		5.2800
# ni             	9		3.2145
# kenapa         	9		3.0482
# susah          	9		1.6701
# kecuali        	9		0.9525
# kaum           	8		2.6419
# kelas          	8		2.3139
# maaf           	8		1.7197
# naek           	8		1.9253
# ntar           	8		2.0999
# loh            	8		2.2826
# prank          	8		2.9171
# cek            	8		1.8698
# deh            	8		2.1860
# enak           	8		2.1618
# siapa          	8		3.5723
# beberapa       	8		1.8662
# allah          	8		2.7612
# kocak          	8		2.2196
# saat           	8		2.1415
# bingung        	8		2.7002
# umum           	8		1.4859
# bermotor       	8		1.6602
# hunian         	8		1.5639
# senjata        	8		1.1880
# bang           	8		2.7821
# mantap         	8		4.0875
# peraturan      	8		1.4587
# depan          	8		2.1130
# google         	8		2.2462
# hari           	8		2.0527
# masa           	8		2.2907
# juta           	8		1.9746
# keren          	8		3.2169
# belanja        	8		1.8588
# oleh           	8		1.8011
# maksudnya      	8		2.5035
# adalah         	8		1.8615
# memang         	8		1.8597
# setuju         	8		2.9326
# ngga           	8		2.9419
# menteri        	8		1.9992
# tertentu       	8		1.0318
# contohnya      	8		3.3253
# menurut        	8		3.1018
# kesehatan      	7		1.6412
# benar          	7		1.8047
# apartemen      	7		1.0787
# ngomong        	7		2.1973
# gtu            	7		2.1935
# demo           	7		1.4858
# the            	7		2.0177
# yakin          	7		2.2356
# up             	7		2.2979
# duit           	7		1.7940
# siap           	7		2.6011
# brg            	7		2.5966
# setiap         	7		1.5072
# khusus         	7		1.8976
# kapal          	7		1.1498
# pesiar         	7		1.1498
# sekolah        	7		1.0994
# sm             	7		1.7019
# asal           	7		2.2181
# bawah          	7		1.5938
# satu           	7		1.5951
# listrik        	7		2.2091
# sebelumnya     	7		2.0175
# gue            	7		2.1462
# ko             	7		2.6256
# keluar         	7		1.8445
# katanya        	7		1.6414
# jokowi         	7		2.0713
# hpp            	7		1.7706
# ah             	7		2.5573
# tunjangan      	7		1.7895
# tanpa          	7		1.8843
# usah           	7		1.7486
# pakai          	7		1.6993
# api            	7		1.0137
# kayaknya       	7		2.1530
# cara           	7		1.4378
# spt            	7		2.5287
# sana           	7		1.0896
# krna           	7		1.6154
# kmrn           	7		2.0884
# menjadi        	7		1.2108
# cukup          	7		2.1279
# yah            	7		2.2722
# lapangan       	7		2.6747
# wajib          	7		1.6443
# serius         	7		2.1686
# bs             	7		2.1871
# butuh          	7		1.0884
# terimakasih    	7		2.5329
# wkwk           	7		2.3177
# brp            	7		2.2617
# pulsa          	7		3.0541
# nominal        	7		2.0321
# ikut           	7		1.5954
# angkutan       	7		0.7487
# oke            	7		2.4215
# umur           	6		1.9801
# koruptor       	6		1.4559
# kenakan        	6		1.0627
# bpk            	6		2.3676
# viral          	6		1.0546
# awal           	6		1.1950
# sekali         	6		1.1984
# 20             	6		1.7596
# komen          	6		2.0412
# to             	6		1.6225
# amat           	6		1.7241
# dah            	6		1.9445
# berlian        	6		1.2810
# protes         	6		1.7876
# beneran        	6		2.1196
# tambah         	6		2.1226
# eh             	6		1.4316
# semuanya       	6		1.2789
# nggak          	6		1.8877
# pertanyaan     	6		1.7662
# dilapangan     	6		1.8984
# berita         	6		1.8446
# dijawab        	6		1.5582
# ternyata       	6		1.9825
# tegas          	6		2.3810
# sejak          	6		1.4773
# untung         	6		2.4557
# kasian         	6		1.8780
# an             	6		1.7232
# rb             	6		1.4012
# balon          	6		1.1265
# bulan          	6		1.3888
# lama           	6		1.3807
# dia            	6		1.9490
# abah           	6		2.2106
# bagus          	6		2.2431
# y              	6		0.0000
# sini           	6		1.0521
# sangat         	6		1.3622
# wartawan       	6		1.5722
# nama           	6		1.2518
# kek            	6		2.0635
# keatas         	6		1.8692
# bbm            	6		1.4426
# kurang         	6		1.5478
# umr            	6		2.2471
# berbeda        	6		1.4127
# kyk            	6		2.0390
# aman           	6		2.0734
# k              	6		0.0000
# ujung          	6		1.6831
# lainnya        	6		1.0429
# seluruh        	6		1.5035
# media          	6		1.4117
# publik         	6		1.1036
# pekerjaan      	6		0.2979
# detail         	6		2.1230
# dikonsumsi     	6		1.0398
# jual           	5		1.0224
# kalangan       	5		1.6983
# dinaikin       	5		1.7780
# supaya         	5		0.8966
# sri            	5		1.9114
# semakin        	5		1.3422
# nyari          	5		1.3019
# terakhir       	5		0.9961
# begini         	5		1.6573
# karna          	5		1.1361
# apalagi        	5		1.4264
# selektif       	5		2.1180
# is             	5		1.4424
# bantuan        	5		0.5017
# mall           	5		1.2607
# perhiasan      	5		1.0431
# tangan         	5		1.4670
# properti       	5		0.7272
# seni           	5		0.3108
# emas           	5		0.9528
# batu           	5		0.8347
# makanya        	5		1.2956
# walaupun       	5		1.3331
# spesifik       	5		1.9998
# lumayan        	5		1.3832
# jalan          	5		0.8687
# mba            	5		1.4805
# skrng          	5		1.0079
# semangat       	5		1.6282
# konsumen       	5		1.0648
# aset           	5		0.9307
# ketika         	5		1.6907
# dg             	5		1.3919
# ama            	5		1.3904
# negri          	5		1.4397
# subsidi        	5		1.4873
# 50             	5		1.3295
# revisi         	5		1.7072
# periode        	5		1.7590
# kriteria       	5		2.1281
# lindungi       	5		1.4723
# menjawab       	5		1.4056
# kamu           	5		1.8304
# ad             	5		1.6513
# jdi            	5		1.0405
# kondominium    	5		0.6714
# sebut          	5		1.0193
# dibilang       	5		1.4271
# kembali        	5		1.4534
# kepada         	5		1.0371
# hutang         	5		0.8998
# merasa         	5		1.5775
# orng           	5		0.8363
# golongan       	5		1.0624
# pas            	5		1.2342
# pilih          	5		1.7292
# gua            	5		1.2830
# pihak          	5		0.9063
# kapan          	5		1.6131
# nasi           	5		1.8784
# president      	5		1.3257
# biasanya       	5		1.3813
# tempat         	5		1.4939
# yaaa           	5		2.1453
# dampaknya      	5		1.7098
# kabar          	5		1.4330
# minyak         	5		1.7378
# murah          	5		1.3038
# mikir          	5		1.6041
# list           	5		2.0128
# jauh           	5		1.7117
# ambigu         	5		1.9212
# bm             	5		2.2262
# kata2          	5		1.3338
# abu2           	5		1.5235
# dri            	5		1.5631
# penjelasannya  	5		1.7494
# boleh          	5		1.4035
# pakk           	5		2.3529
# sprti          	5		1.4086
# internet       	5		2.0876
# sejenisnya     	5		0.8131
# masalah        	5		0.9415
# pajek          	5		0.9160
# dkk            	5		0.7839
# dampak         	5		1.3511
# apa2           	5		1.2576
# ibu            	5		0.8279
# gas            	5		1.8991
# branded        	5		1.7873
# pasar          	5		1.3183
# standar        	5		1.3879
# kepentingan    	5		0.6389
# keperluan      	5		0.5418
# pon            	5		0.6330
# turunin        	4		1.4248
# tenang         	4		0.9411
# sekalian       	4		1.2438
# thn            	4		1.1640
# 2014           	4		0.9375
# msh            	4		1.2941
# anu            	4		1.2995
# anda           	4		1.6900
# bakso          	4		1.2117
# ingat          	4		1.4295
# nyinyir        	4		1.4828
# kemaren        	4		1.3922
# amanah         	4		1.1573
# masalahnya     	4		1.6148
# makasih        	4		2.4060
# naikan         	4		1.5019
# misal          	4		1.2078
# you            	4		1.4830
# rela           	4		1.0301
# alam           	4		0.8704
# cepat          	4		1.0544
# dapet          	4		1.2896
# bodoh          	4		1.3180
# per            	4		1.1168
# perbulan       	4		1.0157
# berikut        	4		0.6901
# elektronik     	4		0.4963
# samsung        	4		0.6107
# laptop         	4		1.0945
# minuman        	4		0.6358
# konteks        	4		0.9286
# cm             	4		1.0321
# mati           	4		0.9861
# mepet          	4		1.9835
# sawah          	4		1.9835
# template       	4		1.4992
# apaan          	4		2.3880
# 10jt           	4		1.1892
# pdhl           	4		1.0561
# kiri           	4		1.1318
# kanan          	4		1.1318
# masyaallah     	4		2.0237
# buruh          	4		1.2835
# efek           	4		1.4932
# bakalan        	4		1.0726
# domino         	4		1.4932
# 500rb          	4		1.5536
# desa           	4		0.6607
# luas           	4		0.7953
# yntkts         	4		1.8727
# 25             	4		2.1594
# negeri         	4		0.9333
# i              	4		0.0000
# klasifikasi    	4		1.3933
# potongan       	4		1.1839
# berasa         	4		0.9087
# dijelaskan     	4		1.5217
# bu             	4		1.3489
# love           	4		1.5962
# pernah         	4		1.0370
# segala         	4		1.1005
# sejahtera      	4		1.0144
# hitung         	4		1.2137
# berdasarkan    	4		1.2972
# apartment      	4		1.0440
# sebelum        	4		1.0208
# sektor         	4		1.2985
# gmna           	4		1.8019
# adil           	4		1.4953
# orang2         	4		1.2456
# ngerti         	4		1.2148
# relatif        	4		1.5635
# lho            	4		1.3965
# jenis          	4		1.1442
# bantu          	4		0.9150
# hukum          	4		1.2259
# perjelas       	4		0.9826
# hartanya       	4		0.9178
# 1jt            	4		1.5436
# sdm            	4		1.1116
# disini         	4		0.9935
# enggak         	4		1.7828
# sering         	4		1.0593
# program        	4		0.5530
# fix            	4		2.0134
# top            	4		2.4371
# setidaknya     	4		1.1673
# nda            	4		1.6109
# 100            	4		1.0731
# januari        	4		0.8973
# ono            	4		1.1074
# dlu            	4		0.8979
# sumber         	4		0.8585
# bedanya        	4		1.8097
# imbasnya       	4		0.9552
# kategorinya    	4		1.4333
# diluar         	4		0.7980
# brang          	4		1.2282
# terlalu        	4		1.1387
# suruh          	4		1.0491
# jelasin        	4		1.1291
# noh            	4		1.2420
# dimana         	4		0.9169
# 5jt            	4		1.8343
# kayanya        	4		1.4663
# bnyak          	4		0.8536
# kau            	4		1.9687
# soal           	4		0.7747
# dimaksud       	4		0.8856
# maka           	4		1.0634
# sedang         	4		1.0259
# susu           	4		0.7015
# turun          	4		1.3319
# ikutan         	4		1.8472
# disebut        	4		1.6061
# main           	4		1.2287
# memiliki       	4		0.8700
# kemenkeu       	4		1.1602
# alah           	4		1.4723
# biaya          	4		0.8939
# perubahan      	4		1.3615
# bener2         	4		1.0343
# nye            	4		0.8948
# gratis         	4		1.0034
# wowo           	4		1.7693
# apapun         	4		1.1895
# pura           	4		1.0585
# brand          	4		0.9798
# misalnya       	4		0.9786
# ujungnya       	4		1.6191
# tipu           	4		0.6099
# tunggu         	4		1.3299
# umumnya        	4		0.4764
# cc             	4		0.7171
# jika           	4		0.7981
# mobilmotor     	4		1.1556
# jt             	4		1.5229
# gt             	4		1.7860
# uangnya        	4		1.1064
# sperti         	4		1.2040
# akhirnya       	4		1.4106
# bangunan       	4		0.6755
# terlihat       	4		1.2063
# sosial         	4		0.9839
# pembelian      	4		1.3754
# knp            	4		1.0928
# intinya        	4		1.5619
# akal           	4		1.4072
# pemerintahan   	4		0.9641
# pemasukan      	4		1.0373
# wr             	4		0.1986
# satpam         	4		0.1986
# kta            	4		0.4363
# artinya        	4		0.9562
# tergolong      	4		0.6285
# ngaruh         	4		1.6838
# mkn            	4		1.2670
# praktek        	4		1.3152
# tak            	4		1.1480
# rancu          	4		1.1083
# goreng         	4		1.2742
# penjualan      	4		1.1756
# pp             	4		1.4448
# dipajakin      	4		1.1029
# isu            	3		0.7848
# sedangkan      	3		0.9851
# panjang        	3		1.5697
# la             	3		0.7873
# jajan          	3		1.2468
# gaya           	3		0.8801
# kak            	3		0.6881
# tentu          	3		0.8879
# pro            	3		0.7266
# perasaan       	3		1.1799
# lgi            	3		0.5500
# petugas        	3		0.6974
# secara         	3		0.9886
# seharusnya     	3		0.6499
# pemimpin       	3		0.8676
# tersier        	3		0.8840
# rasanya        	3		0.8383
# menkeu         	3		0.8223
# online         	3		1.1626
# on             	3		0.7841
# sj             	3		0.8260
# plis           	3		0.9212
# datang         	3		0.4704
# perut          	3		0.8299
# rolex          	3		0.5792
# smartphone     	3		0.8045
# luxury         	3		0.3380
# antik          	3		0.1823
# hotel          	3		0.6914
# pinter         	3		0.6738
# 10juta         	3		1.1993
# ombak          	3		0.9908
# kya            	3		0.8370
# belok          	3		0.9541
# otomatis       	3		0.9504
# percaya        	3		1.3332
# ekonomi        	3		0.6675
# ppj            	3		0.5412
# pajakin        	3		0.8288
# emng           	3		1.1217
# menjelaskan    	3		1.0551
# tertulis       	3		0.8214
# dilindungi     	3		1.2303
# tsb            	3		0.8927
# didefinisikan  	3		0.9030
# mulut          	3		0.8841
# antara         	3		0.7531
# pedagang       	3		0.5786
# baju           	3		0.7240
# bekas          	3		0.3400
# kebeli         	3		1.3903
# yaitu          	3		0.6948
# mulyani        	3		1.3201
# opo            	3		0.8233
# hehehe         	3		1.4854
# terbaik        	3		1.6437
# hingga         	3		0.6278
# pegawai        	3		0.4589
# perpajakan     	3		0.4288
# 60             	3		0.4664
# fasilitas      	3		0.5717
# ratusan        	3		0.6487
# mari           	3		0.8064
# dikenai        	3		0.8988
# makmur         	3		0.8731
# tiap           	3		1.0871
# sndiri         	3		0.9232
# mulu           	3		1.0908
# loo            	3		0.9154
# n              	3		0.0000
# boss           	3		0.9855
# kpr            	3		1.6977
# merah          	3		1.1828
# menaikan       	3		0.9059
# my             	3		1.1629
# sehat2         	3		1.3414
# pelan          	3		0.8510
# sebagian       	3		0.6024
# justru         	3		0.7323
# mata           	3		0.7252
# produksi       	3		0.5062
# maupun         	3		0.5214
# tingkat        	3		0.4365
# impor          	3		0.7091
# oh             	3		1.2860
# satunya        	3		0.7353
# klarifikasi    	3		0.7491
# daripada       	3		0.8236
# jawabnya       	3		1.0369
# bpa            	3		0.5451
# min            	3		0.9684
# suami          	3		0.3345
# mu             	3		1.3548
# ngk            	3		0.7180
# menaikkan      	3		0.7169
# tahu           	3		0.5077
# harapan        	3		1.0754
# mendingan      	3		0.7702
# googling       	3		1.3895
# pupuk          	3		1.0427
# gula           	3		1.0148
# takut          	3		0.9790
# kirain         	3		1.0972
# lugas          	3		0.8120
# memahami       	3		0.8962
# klu            	3		0.8532
# aamiin         	3		1.6855
# nilai          	3		0.6942
# tepat          	3		0.4964
# pekerja        	3		0.9254
# pabrik         	3		0.9017
# wabah          	3		1.0664
# sok            	3		0.9133
# masak          	3		0.9217
# silahkan       	3		1.1199
# sulit          	3		0.6081
# bapa           	3		1.0338
# pikir          	3		1.0951
# sma            	3		0.4667
# search         	3		0.7347
# sim            	3		0.7346
# ida            	3		0.8133
# bersyukur      	3		0.7637
# berharap       	3		0.7815
# perusahaan     	3		0.6169
# bekerja        	3		0.4482
# cocok          	3		1.3386
# tukang         	3		0.7495
# indomaret      	3		1.2783
# ppn12          	3		1.0831
# rata           	3		0.8986
# in             	3		0.9608
# penghasilan    	3		0.7215
# dibawah        	3		0.6871
# daya           	3		0.7721
# awas           	3		1.0337
# narasi         	3		0.9045
# pernyataan     	3		0.8847
# lama2          	3		0.9253
# klw            	3		1.0051
# brng           	3		0.7252
# ditetapkan     	3		0.8596
# statement      	3		0.9653
# balik          	3		0.7052
# betul          	3		1.2136
# agus           	3		0.9411
# pakkk          	3		1.4768
# istri          	3		0.5295
# ngaku          	3		1.2685
# teh            	3		1.3183
# ngak           	3		1.2243
# 58             	3		1.4643
# iki            	3		1.2921
# serta          	3		0.5450
# padamu         	3		0.9674
# imbas          	3		0.8711
# se             	3		0.9192
# lamborghini    	3		0.7925
# pick           	3		0.7925
# seharga        	3		0.7968
# pandang        	3		0.6461
# tok            	3		0.7983
# bos            	3		0.7707
# rike           	3		1.0005
# wik            	3		0.6161
# jadinya        	3		1.2939
# rincian        	3		0.8543
# sekedar        	3		1.0258
# katakan        	3		1.0924
# atuh           	3		0.9951
# and            	3		0.9805
# pasal          	3		0.7426
# keputusan      	3		1.1515
# bagian         	3		0.8593
# sanggup        	3		1.3519
# dukung         	3		1.2659
# sprt           	3		1.2465
# omon2          	3		1.3250
# sedikit        	3		0.8945
# regulasi       	3		1.0023
# keuangan       	3		0.5771
# house          	3		0.2412
# sport          	3		0.5785
# pres           	3		0.8946
# kalah          	3		0.8139
# pengertian     	3		1.3688
# pendapatan     	3		0.8887
# nyaa           	3		1.0225
# dana           	3		0.5295
# pie            	3		0.9353
# toko           	3		0.9437
# awalnya        	3		1.2488
# keadilan       	3		1.0968
# warung         	3		0.9435
# rokok          	3		1.5731
# ngibulin       	3		1.3742
# rendah         	3		0.8927
# sayur          	3		1.2612
# kebanyakan     	3		1.0433
# alfa           	3		0.6392
# barang²        	3		0.5514
# mevvah         	3		1.1581
# jwb            	3		0.7304
# kopi           	3		1.4896
# free           	3		0.8595
# terkait        	3		1.1235
# wb             	3		0.1490
# wilayah        	3		0.3205
# kenek          	3		0.5232
# abis           	3		0.6354
# jasa           	3		0.5994
# terjadi        	3		0.6618
# penjual        	3		0.7859
# pelaksanaan    	3		0.9856
# pangan         	3		0.8272
# slalu          	3		0.8854
# baku           	3		0.5503
# membuat        	3		0.6461
# tanggapan      	3		0.5172
# sebutin        	3		1.2274
# sebenarnya     	3		0.6753
# kemasan        	3		0.6359
# gatau          	3		0.8202
# pmi            	3		0.8428
# bergerak       	3		0.7206
# cafe           	3		0.9904
# jet            	3		1.6167
# minta          	3		0.9639
# pendidikan     	3		0.7552
# pungut         	3		0.8863
# range          	3		1.1018
# primer         	3		1.0359
# trs            	3		0.9537
# pandemi        	3		0.7362
# capek          	3		0.6677
# teori          	3		1.1005
# peluru         	3		0.3723
# membantu       	3		0.6031
# layak          	3		0.3869
# apanya         	3		0.9824
# plus           	3		0.5629
# bahan²         	2		0.4350
# yakali         	2		0.7927
# mbak           	2		1.0353
# nafkah         	2		0.4452
# hapuskan       	2		0.5072
# pinjol         	2		0.5407
# hehe           	2		0.4523
# 16             	2		0.5948
# terperinci     	2		0.4006
# sepeda         	2		0.4420
# kategorikan    	2		0.9001
# maklum         	2		0.5206
# ketimbang      	2		0.4334
# sebaiknya      	2		0.7137
# anies          	2		0.8808
# waktu          	2		0.5453
# mendapatkan    	2		0.7026
# tumpang        	2		0.7628
# tindih         	2		0.7628
# cucu           	2		0.4587
# pensiun        	2		0.6460
# menerimanya    	2		0.6416
# sekunder       	2		0.5729
# pokoknya       	2		0.8200
# ppnnya         	2		0.4936
# nyata          	2		0.8478
# kirakira       	2		1.0754
# men            	2		0.7696
# bner           	2		0.5442
# cause          	2		0.5177
# watching       	2		0.7572
# seumur         	2		0.3942
# terkecuali     	2		0.5787
# bencana        	2		0.3813
# cerita         	2		0.4658
# instruksi      	2		0.3843
# lbh            	2		0.6581
# restoran       	2		0.5982
# isi            	2		0.5935
# omon²          	2		0.9907
# loe            	2		0.7129
# milih          	2		0.6462
# co             	2		0.5623
# desainer       	2		0.1136
# louis          	2		0.3783
# vuitton        	2		0.3783
# sepatu         	2		0.3061
# pakaian        	2		0.4509
# gucci          	2		0.3876
# teknologi      	2		0.1285
# tv             	2		0.2653
# pribadi        	2		0.3923
# harta          	2		0.1692
# karya          	2		0.1285
# lukisan        	2		0.1285
# patung         	2		0.1285
# permata        	2		0.4481
# koleksi        	2		0.1136
# perjalanan     	2		0.4025
# fine           	2		0.6050
# perawatan      	2		0.1136
# langka         	2		0.5365
# tergantung     	2		0.3212
# ngeluh         	2		0.5675
# andai          	2		0.6052
# masya          	2		1.0045
# tar            	2		0.6324
# gampang        	2		0.9012
# game           	2		0.8487
# jawabanya      	2		0.7737
# tes            	2		0.8014
# z              	2		0.0000
# 12jt           	2		0.7041
# mudah2an       	2		0.7495
# sein           	2		0.7669
# dengerin       	2		0.7991
# bacot          	2		0.7857
# lewat          	2		0.5946
# dilakukan      	2		0.7141
# mbk            	2		0.5379
# 2024           	2		0.6956
# ma             	2		0.6300
# nantinya       	2		0.6189
# jatuh          	2		0.5158
# test           	2		0.5672
# water          	2		0.6429
# ahirnya        	2		1.0056
# idup           	2		0.9282
# sewot          	2		0.5422
# abuabu         	2		0.6822
# termaksud      	2		0.7522
# aturannya      	2		0.7050
# arloji         	2		0.5709
# kondisi        	2		0.3425
# trauma         	2		0.7102
# kasus          	2		0.5493
# sie            	2		0.9598
# a              	2		0.0000
# b              	2		0.0000
# what           	2		0.6367
# hoax           	2		0.6083
# ok             	2		0.5328
# berdoa         	2		0.5857
# ataupun        	2		0.4651
# terserah       	2		0.6212
# alat           	2		0.6713
# obat           	2		0.6713
# menimbulkan    	2		0.4503
# 13             	2		0.6162
# perampasan     	2		0.5103
# subianto       	2		0.6974
# rakyatnya      	2		0.7686
# 2023           	2		0.5157
# disampaikan    	2		0.9804
# ditulis        	2		0.9039
# bitcoin        	2		0.4074
# daftar         	2		0.6629
# sekitar        	2		0.3396
# macam          	2		0.3906
# dikurangi      	2		0.5735
# pecat          	2		0.9227
# proses         	2		0.5437
# gada           	2		0.9098
# menyebutkan    	2		0.6110
# bayang         	2		0.5872
# selama         	2		0.7120
# hosting        	2		1.1438
# 2x             	2		0.5575
# pertama        	2		0.7432
# penthouse      	2		0.5560
# menjabat       	2		0.6864
# gebrakan       	2		0.8733
# pusing         	2		0.9518
# drpd           	2		1.1205
# dh             	2		0.7287
# terharu        	2		0.7960
# trimakasih     	2		1.0946
# kmren          	2		0.8231
# jngn           	2		0.5589
# padang         	2		0.7578
# karet          	2		0.6332
# guys           	2		0.4507
# jalur          	2		0.2910
# pabrikan       	2		0.5521
# smpai          	2		0.2916
# indo           	2		0.4468
# so             	2		0.5068
# yaudah         	2		1.0880
# yoo            	2		0.7916
# prbwo          	2		0.3495
# anis           	2		0.5214
# wakil          	2		0.3495
# macem          	2		0.3850
# riset          	2		0.5680
# bedakan        	2		1.2784
# hampir         	2		0.3915
# rumahnya       	2		0.4245
# berusaha       	2		0.2808
# brpa           	2		0.5932
# btw            	2		0.5079
# naiknya        	2		0.6077
# tiket          	2		0.8187
# konser         	2		0.6693
# maju           	2		0.7351
# presidenku     	2		0.7837
# gagal          	2		0.5975
# ngatain        	2		0.4822
# aslinya        	2		0.4260
# mendengar      	2		1.1546
# saran          	2		0.4498
# terpercaya     	2		0.5249
# teknis         	2		0.5290
# keadaan        	2		0.6688
# australi       	2		0.4625
# 250            	2		0.4251
# kl             	2		0.9344
# lngsung        	2		0.6167
# pendengung     	2		0.4138
# bla            	2		0.5635
# 50jt           	2		1.0641
# emg            	2		0.4913
# smpe           	2		0.4941
# ungkit         	2		0.6430
# gajinya        	2		0.4697
# potong         	2		0.4956
# wawancara      	2		0.7306
# caranya        	2		0.6686
# diliat         	2		0.4402
# segi           	2		0.6599
# konsisten      	2		0.8399
# ngasih         	2		0.8248
# gess           	2		0.8980
# pnya           	2		0.6536
# kekayaan       	2		0.4423
# denger         	2		0.7505
# hidupnya       	2		0.4957
# mevah          	2		0.9780
# cicilan        	2		0.4345
# utang          	2		0.7874
# maksut         	2		0.5976
# well           	2		1.2329
# kreteria       	2		1.0620
# kadang         	2		0.7898
# celah          	2		0.4780
# nakal          	2		0.4036
# kembalikan     	2		0.4401
# searching      	2		0.7028
# mengerti       	2		0.5310
# dijadikan      	2		0.4831
# terasa         	2		0.5972
# keliling       	2		0.3331
# rebu           	2		0.6685
# inget          	2		0.8360
# tpi            	2		0.8389
# medis          	2		0.9141
# dimasukkan     	2		0.7728
# menekan        	2		0.3125
# gengsi         	2		0.4408
# setengah       	2		0.5796
# dl             	2		0.5515
# ribut          	2		0.6720
# dipotong       	2		0.5782
# upgrade        	2		0.9374
# mewahyang      	2		0.7835
# ipl            	2		0.6594
# alkes          	2		0.5794
# polemik        	2		0.8430
# beri           	2		0.6110
# suatu          	2		0.5097
# alhamdulilah   	2		0.8528
# tetangga       	2		0.5392
# anggaran       	2		0.3874
# 200            	2		0.6399
# manusia        	2		0.7310
# resmi          	2		0.4068
# pusat          	2		0.3926
# ahhh           	2		0.5176
# hrga           	2		0.6500
# pakitu         	2		0.6688
# kualitas       	2		0.7987
# didiskusikan   	2		0.4010
# kemungkinan    	2		0.4049
# kebalikannya   	2		1.0122
# mesti          	2		0.3838
# pembeli        	2		0.2842
# kabur          	2		0.3839
# hmpir          	2		0.4411
# bicara         	2		0.6427
# singkat        	2		0.9506
# tentang        	2		0.7878
# kesejahteraan  	2		0.8664
# pph            	2		0.4378
# ppbm           	2		0.4378
# es             	2		1.0302
# petani         	2		1.0626
# bawang         	2		0.8652
# tolak          	2		0.7379
# kemudian       	2		0.8039
# pilihan        	2		0.9638
# mewakili       	2		1.2576
# hitungan       	2		0.3137
# kagak          	2		0.6563
# pulang         	2		0.5809
# objek          	2		0.3642
# dikit          	2		0.5974
# ituu           	2		0.8089
# panci          	2		0.6863
# sebenernya     	2		0.5617
# m              	2		0.0000
# bebas          	2		1.1017
# giliran        	2		0.5333
# lakukan        	2		0.3661
# kebun          	2		0.9085
# binatang       	2		0.9085
# tembus         	2		0.4283
# fikir          	2		0.6197
# trmsuk         	2		0.6431
# rinci          	2		0.7959
# briefing       	2		0.8095
# tadi           	2		0.8095
# tax            	2		0.7290
# agak           	2		0.8733
# cakep          	2		0.5424
# pt             	2		0.4076
# pencitraan     	2		0.4142
# pr             	2		0.5038
# menikmati      	2		0.9063
# membela        	2		0.3486
# infonya        	2		0.5559
# siang          	2		0.5767
# service        	2		0.5464
# melayani       	2		0.4027
# haha           	2		0.3721
# gpp            	2		0.5264
# anak2          	2		0.6549
# ppnbmnya       	2		0.6999
# nnti           	2		0.7601
# pmk            	2		0.4361
# segera         	2		0.5651
# 7              	2		0.0000
# penyesuaian    	2		0.3618
# keluarga       	2		0.5459
# second         	2		0.7866
# seri           	2		0.5105
# sultan         	2		0.5415
# bata           	2		0.6437
# salut          	2		0.5279
# warna          	2		0.8973
# palsu          	2		0.4178
# covid          	2		0.3097
# bri            	2		0.2848
# mimpi          	2		0.2848
# bangun         	2		0.4050
# ujung2nya      	2		0.6435
# muncul         	2		0.5781
# ane            	2		0.6892
# hai            	2		0.4297
# lanjut         	2		0.4107
# dm             	2		0.4251
# wkkwkw         	2		0.8524
# 250cc          	2		0.8766
# kalimat        	2		0.5368
# hatihati       	2		0.6605
# anggap         	2		0.8031
# simpang        	2		0.5584
# siur           	2		0.5584
# batas          	2		0.4494
# dasar          	2		0.4439
# spesifikasi    	2		0.9058
# premium        	2		0.1577
# kapasitas      	2		0.1577
# mesin          	2		0.1577
# mulia          	2		0.2778
# bentuk         	2		0.1901
# canggih        	2		0.2778
# mengalami      	2		0.1901
# dokumen        	2		0.3373
# terbaru        	2		0.2778
# campur         	2		0.6296
# of             	2		0.4820
# considered     	2		0.4820
# lhoo           	2		0.7656
# teruss         	2		1.2893
# audit          	2		0.3563
# pakek          	2		0.3398
# tuku           	2		0.5286
# duh            	2		0.4925
# meskipun       	2		0.6280
# sepertinya     	2		1.0139
# ganti          	2		0.8240
# dibuat         	2		0.6892
# siapapun       	2		0.7544
# seneng         	2		0.4337
# point          	2		0.5564
# tnya           	2		0.6498
# keliatan       	2		0.7166
# piye           	2		0.8882
# indihome       	2		1.0190
# iku            	2		0.7453
# nyusahin       	2		0.9358
# ampe           	2		0.5549
# prabs          	2		0.7478
# bgt            	2		0.4981
# kosan          	2		0.2839
# kos            	2		0.2839
# doyan          	2		0.5239
# blnja          	2		0.5716
# 10200          	2		0.5257
# iuran          	2		0.7587
# dipungut       	2		0.9103
# boong          	2		0.3811
# bubur          	2		0.4866
# drama          	2		0.6862
# wait           	2		0.6008
# demi           	2		0.5435
# we             	2		0.5625
# wkwkwk         	2		1.1168
# sinonim        	2		0.4728
# artikan        	2		0.5142
# hermes         	2		1.0346
# minjam         	2		0.4314
# menangani      	2		0.4265
# midi           	2		0.3246
# smua           	2		0.5702
# urusin         	2		0.5793
# rampas         	2		0.2508
# ud             	2		0.2508
# ambil          	2		0.5051
# miskinkan      	2		0.2342
# masukin        	2		0.3365
# sihh           	2		0.5698
# kejahatan      	2		0.6519
# tementemen     	2		0.0993
# kenalan        	2		0.0993
# deket          	2		0.0993
# bogor          	2		0.0993
# ijin           	2		0.0993
# ajak2          	2		0.0993
# posisi         	2		0.0993
# ob             	2		0.0993
# roby           	2		0.0993
# 41thn          	2		0.0993
# kirim          	2		0.0993
# email          	2		0.0993
# panggilan2     	2		0.0993
# panggilan      	2		0.0993
# persyaratan    	2		0.0993
# terpenuhi      	2		0.0993
# sertifikat     	2		0.0993
# seharihari     	2		0.0993
# temen2         	2		0.0993
# maap           	2		0.0993
# wassalamualaikum	2		0.0993
# keliru         	2		0.6217
# cop            	2		0.6390
# good           	2		0.8593
# kredit         	2		1.1991
# kriterianya    	2		0.8887
# wah            	2		0.4323
# tersebut       	2		0.3078
# kedepannya     	2		0.8154
# doa            	2		0.8640
# kyak           	2		0.7219
# fashion        	2		0.6235
# pelaku         	2		0.3797
# lokal          	2		0.4577
# oknum          	2		0.7636
# cerdas         	2		0.7939
# bangga         	2		0.6988
# positif        	2		0.3520
# anggota        	2		0.5143
# ac             	2		1.0843
# yh             	2		0.8210
# bawa           	2		0.6478
# penduduk       	2		0.5553
# bumi           	2		0.7450
# pengeluaran    	2		0.4997
# naikk          	2		0.6207
# x              	2		0.0000
# 15rb           	2		0.4722
# 1500           	2		0.5601
# netizen        	2		0.7981
# merata         	2		0.9543
# bli            	2		0.4610
# pengawasan     	2		0.2788
# dijalankan     	2		0.2788
# taun           	2		0.6995
# mencla         	2		0.7898
# mencle         	2		0.7898
# presidennya    	2		0.7356
# 1000           	2		0.6490
# mengikuti      	2		0.4000
# didepan        	2		0.5903
# selain         	2		0.5019
# ki             	2		0.7532
# ungu           	2		0.9144
# sudut          	2		0.4532
# roda           	2		0.7151
# empat          	2		0.7151
# tuk            	2		1.0653
# dibeli         	2		0.7356
# karyawan       	2		0.7520
# 8              	2		0.0000
# keras          	2		0.5952
# konsep         	2		0.4886
# hahaha         	2		0.7472
# hmmm           	2		0.5302
# segitu         	2		0.4181
# rasa           	2		0.6905
# toh            	2		0.5129
# mmg            	2		0.6800
# penjabaran     	2		0.9168
# sebuah         	2		0.5373
# data           	2		0.7795
# konglo         	2		0.7029
# struk          	2		0.5348
# komplen        	2		0.6432
# mengeluh       	2		0.5367
# manis          	2		0.8615
# kartu          	2		0.7884
# nggk           	2		0.8067
# klasifikasinya 	2		0.7513
# djp            	2		0.4227
# as             	2		0.8953
# lambo          	2		0.7099
# jaman          	2		0.6621
# berpenghasilan 	2		0.3466
# menunjukkan    	2		0.3466
# status         	2		0.3466
# males          	2		0.6649
# was            	2		0.4777
# undanganundangan	2		0.4082
# kalu           	2		0.6977
# bijak          	2		0.4853
# tujuannya      	2		0.4881
# adanya         	2		0.5612
# kompak         	2		0.8454
# anjir          	2		0.4603
# beat           	2		0.8595
# permainan      	2		0.5621
# hapus          	2		0.5710
# beban          	2		0.7276
# meminimalisir  	2		0.3924
# digunakan      	2		0.4081
# apbn           	2		0.4822
# komplek        	2		0.6570
# merupakan      	2		0.3563
# nurut          	2		0.7912
# ikn            	2		0.8678
# anjlok         	2		0.6915
# bgini          	2		0.8429
# pelajari       	2		0.3919
# jelasnya       	2		0.5056
# oneng          	2		0.8293
# asia           	2		0.4994
# air            	2		0.4432
# minum          	2		0.4432
# menang         	2		0.3612
# merasakan      	2		0.5283
# lcgc           	2		0.8666
# ambulan        	2		0.1764
# jenazah        	2		0.1764
# pemadam        	2		0.1764
# kebakaran      	2		0.1764
# tahanan        	2		0.1764
# totan          	2		0.1764
# niaga          	2		0.1764
# pariwisata     	2		0.1764
# hrs            	2		0.5714
# beda2          	2		0.7502
# frugal         	2		0.5974
# living         	2		0.5974
# go             	2		0.6947
# undang         	2		0.5384
# terhadap       	2		0.4606
# detailnya      	2		0.9079
# bsa            	2		0.7400
# pelaksanaanya  	2		0.4808
# melindungi     	2		0.8452
# bilangnya      	2		0.8106
# pecel          	2		0.5453
# atu            	2		0.6829
# gaes           	2		1.1337
# alasan         	2		0.5329
# kismin         	2		0.9013
# pembayaran     	2		0.7236
# laman          	2		0.7195
# mlh            	2		0.2532
# mna            	2		0.2532
# rumus          	2		0.5407
# boneka         	2		0.4748
# muliono        	2		0.4748
# pengemis       	2		0.6386
# yuk            	2		0.3753
# hak            	2		0.3180
# karyawanburuh  	2		0.3180
# mjd            	2		0.4136
# macet          	2		0.5769
# distributor    	1		0.2175
# kue            	1		0.2175
# rame           	1		0.2175
# ngumumin       	1		0.2175
# mikir²         	1		0.2175
# barng          	1		0.4308
# middle         	1		0.4308
# nggeh          	1		0.5875
# ngoten         	1		0.5875
# menentang      	1		0.4606
# mempunyai      	1		0.4606
# kroninya       	1		0.4606
# bapake         	1		0.5774
# bobi           	1		0.5774
# kertanegara    	1		0.5774
# berjibaku      	1		0.5708
# seblak         	1		0.5633
# tambahin       	1		0.4508
# dalem          	1		0.4508
# kurung         	1		0.4508
# ketauan        	1		0.4508
# dagangannya    	1		0.3948
# harganyatetep  	1		0.3948
# alhamdlillah   	1		0.4181
# presidrn       	1		0.4181
# kuu            	1		0.4181
# boos           	1		0.1917
# sekalipun      	1		0.1917
# memberat       	1		0.1917
# pakkarena      	1		0.1917
# kwajiban       	1		0.1917
# berikan        	1		0.1917
# mencari        	1		0.1917
# hidupsbb       	1		0.1917
# mencapai       	1		0.1917
# diwawancarai   	1		0.5043
# brdain         	1		0.7381
# alhamdulillahbu	1		0.4318
# acc            	1		0.4318
# taoi           	1		0.4318
# pinjol2        	1		0.3550
# marak          	1		0.3550
# merusak        	1		0.3550
# tanggah        	1		0.3550
# mcdonalds      	1		0.3026
# lagian         	1		0.3026
# diboikot       	1		0.3026
# sebijak        	1		0.2938
# sekarangdulu   	1		0.2938
# max            	1		0.4241
# catat          	1		0.3156
# dijidat        	1		0.3156
# selah          	1		0.3156
# jabarkan       	1		0.6961
# ngawur         	1		0.2003
# pertegas       	1		0.2003
# bentuknya      	1		0.2003
# ide            	1		0.4008
# kampanye       	1		0.4008
# debat          	1		0.4008
# nyicil         	1		0.5270
# sebagainya     	1		0.2651
# lupa           	1		0.2651
# koar           	1		0.6677
# matur          	1		0.6150
# suwun          	1		0.6150
# nyookkkkite    	1		0.5774
# joged          	1		0.5774
# barengbareng   	1		0.5774
# idealisme      	1		0.7178
# niatnya        	1		0.2451
# digolongkan    	1		0.2451
# robb           	1		0.2950
# berikanlah     	1		0.2950
# selamatkan     	1		0.2950
# zalim          	1		0.2950
# janganlah      	1		0.3881
# merembet       	1		0.7452
# coment         	1		0.4033
# bermutu        	1		0.4033
# kawal          	1		0.5290
# ekstra         	1		0.3476
# joget2         	1		0.3472
# pilpres        	1		0.3472
# jogetin        	1		0.3472
# ratarata       	1		0.3111
# gamau          	1		0.3111
# sejati         	1		0.3111
# keburu         	1		0.5615
# menko          	1		0.3848
# hatga          	1		0.2582
# mulay          	1		0.2582
# percobaan      	1		0.2582
# menerapkn      	1		0.2582
# kenaikn        	1		0.2582
# gapapa         	1		0.4133
# hamya          	1		0.4133
# kolelsi        	1		0.4133
# driver         	1		0.3868
# potongane      	1		0.3868
# ngakunya       	1		0.3807
# kenyataan      	1		0.3807
# bedakebiasaan  	1		0.3807
# nipunegoro     	1		0.3807
# better         	1		0.2942
# hold           	1		0.2942
# your           	1		0.2942
# word           	1		0.2942
# working        	1		0.2942
# class          	1		0.2942
# definisikan    	1		0.9083
# plia           	1		0.1907
# baik2          	1		0.1907
# tangani        	1		0.1907
# tersalurkan    	1		0.1907
# bwrlomba2      	1		0.4765
# label          	1		0.4765
# make           	1		0.4645
# ketebelen      	1		0.4645
# mubadzir       	1		0.4645
# wawancaranya   	1		0.4782
# artis2         	1		0.2662
# celebrity      	1		0.2662
# tuber          	1		0.2662
# konten         	1		0.2662
# kreator        	1		0.2662
# hobby          	1		0.2662
# pamer          	1		0.2662
# kenyataannya   	1		0.7160
# terapkan       	1		0.2735
# tenant         	1		0.2735
# kapok          	1		0.2735
# sebesar        	1		0.2735
# kmarin         	1		0.3288
# oktober        	1		0.3288
# 2jt            	1		0.3288
# konsumsi       	1		0.0568
# emasberlian    	1		0.0568
# tiffany        	1		0.0568
# cartier        	1		0.0568
# jam            	1		0.0568
# patek          	1		0.0568
# philippe       	1		0.0568
# chanel         	1		0.0568
# hermès         	1		0.0568
# christian      	1		0.0568
# louboutin      	1		0.0568
# jimmy          	1		0.0568
# choo           	1		0.0568
# prada          	1		0.0568
# versace        	1		0.0568
# galaxy         	1		0.0568
# edisi          	1		0.0568
# gaming         	1		0.0568
# macbook        	1		0.0568
# dell           	1		0.0568
# xps            	1		0.0568
# smartwatch     	1		0.0568
# apple          	1		0.0568
# watch          	1		0.0568
# tag            	1		0.0568
# heuer          	1		0.0568
# headphone      	1		0.0568
# sennheiser     	1		0.0568
# bose           	1		0.0568
# 4k8k           	1		0.0568
# qled           	1		0.0568
# oled           	1		0.0568
# mercedesbenz   	1		0.0568
# sclass         	1		0.0568
# bmw            	1		0.0568
# 7series        	1		0.0568
# harleydavidson 	1		0.0568
# ducati         	1		0.0568
# yacht          	1		0.0568
# cessna         	1		0.0568
# gulfstream     	1		0.0568
# investasi      	1		0.0568
# villa          	1		0.0568
# perak          	1		0.0568
# batangan       	1		0.0568
# lainlain       	1		0.0568
# paket          	1		0.0568
# wisata         	1		0.0568
# penginapan     	1		0.0568
# bintang        	1		0.0568
# kaviar         	1		0.0568
# anggur         	1		0.0568
# tubuh          	1		0.0568
# spa            	1		0.0568
# kulit          	1		0.0568
# diingat        	1		0.0568
# bahwa          	1		0.0568
# berbedabeda    	1		0.0568
# individu       	1		0.0568
# bgs            	1		0.2368
# ngarepin       	1		0.2368
# nasbung        	1		0.2368
# ngarep         	1		0.2368
# majunya        	1		0.3733
# tabarakallah   	1		0.5219
# sehat²         	1		0.5219
# respect        	1		0.3257
# over           	1		0.3257
# dirinci        	1		0.4765
# takutnya       	1		0.4765
# ketahuan       	1		0.4765
# blablablaaa    	1		0.3471
# pemerintahawal 	1		0.2907
# rilis          	1		0.2907
# siap2          	1		0.2907
# asli           	1		0.4920
# no             	1		0.4920
# mengklarifikasi	1		0.2925
# jumlahnya      	1		0.2925
# plasebo        	1		0.2925
# tumpuk         	1		0.3722
# tumpukan       	1		0.3722
# crypto         	1		0.4871
# gha            	1		0.3787
# disosmed       	1		0.3787
# slip           	1		0.3550
# bukti          	1		0.3550
# ketiduran      	1		0.2689
# tuhkan         	1		0.2689
# bentar         	1		0.2689
# naikkansekalian	1		0.2689
# jgk            	1		0.2689
# ngeles         	1		0.4263
# intan          	1		0.4162
# maybe          	1		0.4162
# yes            	1		0.4162
# tolonglah      	1		0.1804
# 45rb           	1		0.1804
# penerangan     	1		0.1804
# gelap          	1		0.1804
# kmn            	1		0.1804
# usul           	1		0.1804
# papah          	1		0.4999
# alahamdulillah 	1		0.4519
# wkwkkw         	1		0.2711
# kalender       	1		0.5776
# hahahaa        	1		0.4355
# otaknya        	1		0.4355
# smph           	1		0.4355
# bajak          	1		0.2663
# celana         	1		0.2663
# oho            	1		0.1482
# tentubisa      	1		0.1482
# terpilih       	1		0.1482
# persiapan      	1		0.1482
# kebijakannya   	1		0.1482
# sematang       	1		0.1482
# sekaranglihat  	1		0.1482
# tragedi        	1		0.1482
# 98             	1		0.1482
# dikit2         	1		0.1482
# dikait2kanbelum	1		0.1482
# persoalan      	1		0.1482
# ham            	1		0.1482
# balikan        	1		0.1482
# istrinyalah    	1		0.1482
# orba           	1		0.1482
# terulangbeliau 	1		0.1482
# sedewasa       	1		0.1482
# menghadapi     	1		0.1482
# permasalahan   	1		0.1482
# iniambil       	1		0.1482
# postifnya      	1		0.1482
# tertempa       	1		0.1482
# besok          	1		0.3608
# generasi       	1		0.3608
# sandwich       	1		0.3608
# inews          	1		0.4198
# garudatv       	1		0.4198
# know           	1		0.4198
# are            	1		0.4198
# tanah          	1		0.7127
# rombak         	1		0.4653
# pelaksana      	1		0.3197
# beradu         	1		0.3197
# guru2jt        	1		0.4353
# its            	1		0.2752
# budayakan      	1		0.2363
# melihat        	1		0.2363
# membaca        	1		0.2363
# kesalah        	1		0.2363
# pahaman        	1		0.2363
# kebenaran      	1		0.2363
# berkomentar    	1		0.2363
# mantep         	1		0.4973
# seorang        	1		0.4973
# jutapada       	1		0.2596
# pindahan       	1		0.2596
# taiwantapi     	1		0.2596
# bole           	1		0.2596
# masnya         	1		0.6437
# madep          	1		0.6668
# uing           	1		0.6668
# lagisegera     	1		0.4169
# tuntaskan      	1		0.4169
# sayang         	1		0.3184
# titipan        	1		0.3184
# apá            	1		0.2620
# th             	1		0.2620
# srg            	1		0.2620
# menjerat       	1		0.2620
# pesta          	1		0.2620
# membangun      	1		0.2620
# menanggungnya  	1		0.2620
# hallah         	1		0.5292
# iyo            	1		0.5292
# gausah         	1		0.5501
# egk            	1		0.2894
# memjankan      	1		0.2894
# kemewahan      	1		0.2894
# dekat          	1		0.4389
# refferal       	1		0.2037
# bioku          	1		0.2037
# milyar         	1		0.2037
# 500juta        	1		0.2037
# november       	1		0.2037
# manurut        	1		0.1697
# infrastruktur  	1		0.1697
# keamaanan      	1		0.1697
# ...
# chitatotango   	1		0.2233
# pk             	1		0.7316
# penasaran      	1		0.8441
# seh            	1		0.4219
# keberlanjutan  	1		0.4219
# besar2         	1		0.4219
# mulyonobiar    	1		0.4013
# mangkrak       	1		0.4013
# penumpang      	1		0.2640
# perbanyak      	1		0.2640
# jabatan        	1		0.4887
# uangan         	1		0.4043
# sono           	1		0.4043
# prabowoo       	1		0.4247
# sedia          	1		0.4247
# followets      	1		0.4247
# giys           	1		0.4247
# modal          	1		0.3556
# kabarnya       	1		0.4070
# nolak          	1		0.4070
# implemtasiny   	1		0.3129
# project        	1		0.3129
# pmrntah        	1		0.3129
# dbawah         	1		0.3129
# 1m             	1		0.3129
# bagasi         	1		0.4652
# tki            	1		0.4652
# oposisi        	1		0.6612
# rusak          	1		0.2750
# rencana        	1		0.2750
# sertipikasi    	1		0.2750
# cair           	1		0.2750
# job            	1		0.5875
# pap            	1		0.5875
# baut           	1		0.6308
# titanium       	1		0.6308
# mksdnya        	1		0.5900
# titan          	1		0.5900
# banter         	1		0.2833
# solaria        	1		0.2833
# ciki           	1		0.3205
# box            	1		0.3205
# pemahaman      	1		0.1970
# 12kita         	1		0.1970
# berkat         	1		0.4106
# alias          	1		0.4106
# tertinggi      	1		0.2497
# urutan         	1		0.2497
# terendah       	1		0.2497
# dipaksa        	1		0.2497
# sakit          	1		0.2497
# begimana       	1		0.3611
# nasib          	1		0.5726
# belah          	1		0.3465
# pmilu          	1		0.1806
# 1th            	1		0.1806
# tarung         	1		0.1806
# 2029           	1		0.1806
# akur2          	1		0.1806
# dululah        	1		0.1806
# suport         	1		0.1806
# kalaucma       	1		0.1806
# mikirin        	1		0.1806
# ruwet          	1		0.1806
# pakjangankan   	1		0.3853
# naikisu        	1		0.3853
# naikmahal      	1		0.3853
# tingal         	1		0.4163
# darimana       	1		0.4163
# ckakkaa        	1		0.4975
# jebakan        	1		0.4975
# betmen         	1		0.4975
# berubah        	1		0.3710
# dung           	1		0.4547
# nikmatin       	1		0.4547
# sapa           	1		0.4547
# shope          	1		0.4105
# receh          	1		0.4105
# blunderkategori	1		0.2458
# subyektif      	1		0.2458
# bgtkemaren     	1		0.2458
# dihari         	1		0.2458
# 1x             	1		0.2458
# gapok          	1		0.2458
# zonk           	1		0.2458
# pakdahlah      	1		0.2458
# byeee          	1		0.2458
# pke            	1		0.5504
# am             	1		0.5642
# dongs          	1		0.4284
# nanyak         	1		0.4220
# mikro          	1		0.4135
# 61             	1		0.0923
# 2020           	1		0.0923
# ayah           	1		0.3466
# diler          	1		0.3466
# penjualannya   	1		0.3466
# lhoooo         	1		0.7016
# ujung2         	1		0.2179
# nyerempet      	1		0.2179
# kemana         	1		0.2179
# sihdari        	1		0.2179
# komunikasi     	1		0.2179
# terkesan       	1		0.2179
# setengah2      	1		0.2179
# trsjarang      	1		0.2179
# skali          	1		0.2179
# terdengar      	1		0.2179
# clear          	1		0.2179
# 2025kalau      	1		0.3554
# kebijakannyajgn	1		0.3554
# transparant    	1		0.3871
# penggunaanya   	1		0.3871
# ketidaknyamanannya	1		0.1925
# im3            	1		0.1925
# melakukan      	1		0.1925
# namun          	1		0.1925
# menyediakan    	1		0.1925
# terjangkau     	1		0.1925
# aktif          	1		0.1925
# kuki           	1		0.1925
# waspada        	1		0.4413
# reaksi         	1		0.4413
# berantai       	1		0.4413
# caranyayang    	1		0.5446
# kawan          	1		0.3742
# 3050           	1		0.2994
# mbps           	1		0.2994
# halo           	1		0.2994
# 100rb          	1		0.2994
# jga            	1		0.2994
# mewahmohon     	1		0.4006
# ngiklan        	1		0.2656
# meta           	1		0.2656
# ads            	1		0.2656
# digital        	1		0.2656
# sempak         	1		0.5146
# man            	1		0.5146
# crocodile      	1		0.5146
# kopi2an        	1		0.6724
# bermerek       	1		0.6724
# inyaalloh      	1		0.2259
# memajukan      	1		0.2259
# mmprbnyk       	1		0.2259
# mngurangi      	1		0.2259
# pengangguran   	1		0.2259
# kjahatan       	1		0.2259
# doakn          	1		0.2259
# slamat         	1		0.2259
# klak           	1		0.2259
# kuburny        	1		0.2259
# teorinya       	1		0.5219
# prakteknya     	1		0.5219
# alat2          	1		0.4871
# donggg         	1		0.4871
# ucapkan        	1		0.5195
# pengumuman     	1		0.3696
# naiik          	1		0.2692
# parfum         	1		0.6068
# mengucapkan    	1		0.3017
# perhatiaanya   	1		0.3017
# memberlakukan  	1		0.1846
# dngn           	1		0.1846
# 2m             	1		0.1846
# menstimulasi   	1		0.1846
# minat          	1		0.1846
# bidang         	1		0.1846
# sempat         	1		0.1846
# 20212022       	1		0.1846
# gmana          	1		0.4042
# pov            	1		0.4042
# masingmasing   	1		0.4042
# sejarah        	1		0.4885
# berlevel       	1		0.4885
# paknnti        	1		0.6409
# adaa           	1		0.5481
# prabowokita    	1		0.2255
# menunggu       	1		0.2255
# nyamasalah     	1		0.2255
# hidupkami      	1		0.2255
# butuhbiaya     	1		0.2255
# ditinjau       	1		0.2255
# ulang          	1		0.2255
# un             	1		0.2255
# negeriyang     	1		0.2255
# terkadang      	1		0.2255
# ukt            	1		0.2255
# mahaaaal       	1		0.2255
# dikurangin     	1		0.4865
# kebayankan     	1		0.4865
# arti           	1		0.4769
# klawbsa        	1		0.2819
# sklian         	1		0.2819
# muluk          	1		0.2819
# atasnya        	1		0.2819
# syandar        	1		0.2438
# ganda          	1		0.2438
# lagi2          	1		0.2438
# kasta          	1		0.2438
# sementara      	1		0.2438
# sifatnya       	1		0.2438
# memaksa        	1		0.2438
# katagori       	1		0.6148
# undang2        	1		0.2586
# dihukum        	1		0.2586
# foya2          	1		0.2586
# mul            	1		0.3469
# menyangkut     	1		0.3469
# gaakan         	1		0.3469
# perkataan      	1		0.4712
# noted          	1		0.6898
# ndut           	1		0.6767
# engga          	1		0.4730
# hmm            	1		0.4351
# melewati       	1		0.2374
# formula        	1		0.2374
# indomie        	1		0.2374
# didalamnya     	1		0.2374
# komponen       	1		0.2374
# abu2bukanya    	1		0.3872
# lahan          	1		0.3872
# urusan         	1		0.6432
# seringsuka     	1		0.2804
# adu            	1		0.2804
# fakta          	1		0.2804
# membelanjakan  	1		0.2804
# anuu           	1		0.6525
# dealer2        	1		0.4168
# tumbang        	1		0.4168
# esemka         	1		0.4168
# sabun          	1		0.5671
# dianggap       	1		0.5671
# jawabnnya      	1		0.4476
# gendar         	1		0.2563
# ramerame       	1		0.2563
# emperan        	1		0.2563
# nasgor         	1		0.2563
# rumahan        	1		0.2563
# kudune         	1		0.6668
# sayangku       	1		0.6668
# anj            	1		0.2979
# menterinya     	1		0.2979
# gifnya         	1		0.6131
# ngegantung     	1		0.4395
# jadikan        	1		0.2774
# ipon           	1		0.4677
# green          	1		0.4677
# nongkrong2     	1		0.1247
# bar            	1		0.1247
# diskotik       	1		0.1247
# brandit        	1		0.1247
# menerima       	1		0.1247
# silang         	1		0.1247
# hasilnya       	1		0.1247
# bangku         	1		0.1247
# awasi          	1		0.1247
# nys            	1		0.1247
# menyalurkan    	1		0.1247
# nyampe         	1		0.1247
# 8rb            	1		0.1247
# woyyy          	1		0.4318
# appartmenkondominumdll	1		0.2229
# hypertmartindomart	1		0.2229
# cari2          	1		0.4119
# drastis        	1		0.4054
# ertong         	1		0.4737
# preettttomon   	1		0.2486
# sandang        	1		0.2486
# time           	1		0.2486
# browsing       	1		0.2873
# buuuu          	1		0.2873
# ampunn         	1		0.2873
# ig             	1		0.2873
# bukak          	1		0.2873
# pakmasa        	1		0.4507
# jangaan        	1		0.3919
# dinaikkn       	1		0.3919
# keabisan       	1		0.3897
# nyerangnya     	1		0.3897
# mendengarkan   	1		0.4339
# suara          	1		0.4339
# pdip           	1		0.4339
# eehh           	1		0.2713
# guru2          	1		0.2713
# karma          	1		0.2713
# dibedakan      	1		0.4202
# ttup           	1		0.4315
# gorwng         	1		0.4315
# gaterima       	1		0.3297
# diperjuangin   	1		0.3297
# tuuuh          	1		0.2824
# waranya        	1		0.6068
# bandingin      	1		0.4445
# pengelolaan    	1		0.4445
# jepang         	1		0.4445
# nyatanya       	1		0.3844
# dimksd         	1		0.5425
# serupa         	1		0.3346
# hati²          	1		0.3346
# karat          	1		0.3450
# gramnya        	1		0.3450
# sejelas        	1		0.3367
# berpihak       	1		0.4667
# semurah        	1		0.3162
# tissu          	1		0.3162
# modalnya       	1		0.3162
# 1800           	1		0.3162
# yess           	1		0.4357
# ayo            	1		0.2534
# fokuskan       	1		0.2534
# stabil         	1		0.2534
# simpel         	1		0.2085
# mcd            	1		0.2085
# belilah        	1		0.2085
# kaleng2        	1		0.4620
# konsumtif      	1		0.5195
# flagship       	1		0.5195
# story          	1		0.4405
# kalean         	1		0.4405
# elit           	1		0.4405
# panik          	1		0.4405
# knalan         	1		0.1266
# banyakan       	1		0.1266
# mreka          	1		0.1266
# mhl            	1		0.1266
# mncapai        	1		0.1266
# 9000           	1		0.1266
# 6000           	1		0.1266
# bur            	1		0.1266
# mngkn          	1		0.4440
# 500            	1		0.4440
# biwuh          	1		0.5710
# tersendiri     	1		0.5499
# scra           	1		0.5905
# patokannya     	1		0.6450
# sembakonya     	1		0.5574
# kiblatnya      	1		0.3574
# diucap         	1		0.3574
# devinisi       	1		0.2167
# mwah           	1		0.2167
# tny            	1		0.2167
# 10cs           	1		0.2167
# rarusan        	1		0.2167
# akses          	1		0.2227
# pernyataannya  	1		0.2227
# bertumbuh      	1		0.3379
# membeli        	1		0.3379
# perlengkapan   	1		0.3379
# edan           	1		0.3379
# kont           	1		0.4507
# kolom          	1		0.4507
# ikutin         	1		0.1917
# tender         	1		0.1917
# mnt            	1		0.1917
# turunan        	1		0.1917
# pikirkan       	1		0.1917
# halus          	1		0.1917
# q              	1		0.0000
# dihantui       	1		0.4399
# polres         	1		0.4399
# pakaq          	1		0.4399
# 100k           	1		0.7570
# pelan2         	1		0.2161
# mrk            	1		0.2161
# diang          	1		0.2161
# eakyar         	1		0.2161
# dasilitas      	1		0.2161
# ngamuk         	1		0.2161
# gimik          	1		0.2636
# asn            	1		0.2636
# honorer        	1		0.2636
# penyampaian    	1		0.2636
# kenyataanya    	1		0.2636
# eropa          	1		0.1547
# 1518           	1		0.1547
# meningkat      	1		0.1547
# tetapi         	1		0.1547
# nerapin        	1		0.5248
# devisi         	1		0.3794
# barangmewah    	1		0.3794
# siapp2         	1		0.5250
# bara           	1		0.5168
# mewa           	1		0.5168
# wowowo         	1		0.5168
# kesini         	1		0.3868
# cinta          	1		0.3868
# paaakkkk       	1		0.3868
# mobilmotorhp   	1		0.3017
# amnesti        	1		0.3017
# pakkasihan     	1		0.3017
# menyiksa       	1		0.3017
# standard       	1		0.9083
# printer        	1		0.5072
# scanner        	1		0.5072
# lcd            	1		0.5072
# aneh           	1		0.6800
# ditunggu       	1		0.3955
# staf           	1		0.5676
# diperjelas     	1		0.3435
# nebak2         	1		0.3435
# mayur          	1		0.5507
# smart          	1		0.4805
# user           	1		0.4805
# kurangin       	1		0.6838
# thun           	1		0.2175
# 2021           	1		0.2175
# terkena        	1		0.2175
# relaksasi      	1		0.2175
# berrti         	1		0.2175
# dicabut        	1		0.2175
# kesampean      	1		0.3768
# produknya      	1		0.2927
# digass         	1		0.2927
# product        	1		0.5433
# adobe          	1		0.5433
# kenak          	1		0.5433
# pd             	1		0.2676
# e              	1		0.0000
# aturane        	1		0.2676
# bawahan2       	1		0.4554
# tagihan        	1		0.6391
# diberi         	1		0.2743
# baso           	1		0.4389
# beranaktahu    	1		0.4389
# gejrot         	1		0.4389
# copot          	1		0.4103
# hobi           	1		0.4103
# menindas       	1		0.4103
# lbih           	1		0.2572
# sblmnyasetiap  	1		0.2572
# jwbnya         	1		0.2572
# gtau           	1		0.2572
# oo             	1		0.2572
# diemdiem       	1		0.2572
# ketok          	1		0.2572
# palu           	1		0.2572
# memori         	1		0.1528
# ayat           	1		0.1528
# selengkapnya   	1		0.1528
# ortax          	1		0.1528
# httpsortaxorgmempelajariapayangdimaksuddenganppnbm	1		0.1528
# dirjen         	1		0.5569
# full           	1		0.5569
# senyum         	1		0.5569
# tenane         	1		0.6117
# lik            	1		0.6117
# beda2in        	1		0.2374
# mikiri         	1		0.2374
# promax         	1		0.3523
# jta            	1		0.3523
# alphard        	1		0.3523
# perhatikan     	1		0.2790
# undang²        	1		0.2790
# pakhidup       	1		0.3612
# prabowomreka   	1		0.3612
# pantesss       	1		0.3612
# bedain         	1		0.5366
# jirr           	1		0.6597
# 60jt           	1		0.5051
# lele           	1		0.3193
# bungkus        	1		0.3193
# tah            	1		0.4648
# maknya         	1		0.4041
# jurnal         	1		0.4041
# artikel        	1		0.4041
# tnng           	1		0.4041
# smakin         	1		0.3782
# sempet         	1		0.3778
# miskuuin       	1		0.4831
# resah          	1		0.4831
# pko            	1		0.3575
# mngkin         	1		0.3575
# diratakan      	1		0.3569
# hny            	1		0.2790
# aduk           	1		0.2790
# diprank        	1		0.5504
# tuhkaaan       	1		0.1876
# promo          	1		0.1876
# nyesel         	1		0.1876
# profile        	1		0.1876
# chat           	1		0.1876
# double         	1		0.4946
# konteksnya     	1		0.3063
# dasarnya       	1		0.3063
# informasi      	1		0.3063
# mengandung     	1		0.3063
# makna          	1		0.3063
# 1gaji          	1		0.1590
# pembisnis      	1		0.1590
# asasi          	1		0.1590
# benanr2        	1		0.1590
# organisasi     	1		0.1590
# kusus          	1		0.1590
# meriksa        	1		0.1590
# eksekusi       	1		0.1590
# melanggar      	1		0.1590
# kemanusiaan    	1		0.1590
# brarti         	1		0.4046
# opsi           	1		0.4046
# tolol          	1		0.4211
# redmi          	1		0.6588
# batubara       	1		0.6559
# monggo         	1		0.4894
# wesss          	1		0.4338
# sampeyan       	1		0.4338
# difasilitasi   	1		0.4035
# digencet       	1		0.4035
# sebutkan       	1		0.2852
# semen          	1		0.2852
# besi           	1		0.2852
# herbel         	1		0.2852
# enakan         	1		0.3929
# pemerentah     	1		0.2133
# asbun          	1		0.2133
# teralihkan     	1		0.2133
# perincian      	1		0.4101
# trnasuk        	1		0.5095
# rumahtanahmobil	1		0.3876
# mewahmotor     	1		0.3876
# progressivejadi	1		0.3876
# heboh          	1		0.3969
# budi           	1		0.3969
# arie           	1		0.3969
# standarnya     	1		0.4718
# indonesiayang  	1		0.3756
# cuman          	1		0.3756
# buah           	1		0.3756
# billnya        	1		0.2808
# 500k           	1		0.2808
# pola           	1		0.3089
# ketebak        	1		0.3089
# marah          	1		0.3089
# revisibatalin  	1		0.3089
# pahlawan       	1		0.3089
# bong           	1		0.2296
# pakjero        	1		0.5323
# pakir          	1		0.3473
# bis            	1		0.3473
# ancurancuran   	1		0.4026
# hal2           	1		0.4952
# kementrian     	1		0.4952
# xixixix        	1		0.9083
# masuknya       	1		0.4073
# trmsk          	1		0.7577
# skincare       	1		0.7916
# peecaya        	1		0.6445
# perpres        	1		0.4856
# rugi           	1		0.4804
# sdut           	1		0.2068
# pndang         	1		0.2068
# lndasn         	1		0.2068
# kmewahn        	1		0.2068
# jelssin        	1		0.2068
# secra          	1		0.2068
# konkret        	1		0.2068
# sekonkret2nya  	1		0.2068
# trjadi         	1		0.2068
# brita          	1		0.2068
# dkemudian      	1		0.2068
# gx             	1		0.4992
# tdi            	1		0.3407
# mlm            	1		0.3407
# penerus        	1		0.4202
# king           	1		0.4202
# lip            	1		0.4202
# dilihat        	1		0.2485
# s              	1		0.0000
# kemana2        	1		0.2485
# bahkan         	1		0.2485
# mutar2         	1		0.2485
# kampung        	1		0.2485
# motornya       	1		0.2485
# showoom        	1		0.2485
# letak          	1		0.4919
# perbedaannya   	1		0.4919
# mewahnnya      	1		0.4260
# ginigmn        	1		0.4929
# ngeri          	1		0.5675
# sleding        	1		0.5675
# mnyimak        	1		0.6943
# r4             	1		0.3165
# jalanan        	1		0.3165
# gmnaa          	1		0.3501
# aqua           	1		0.3501
# 3k             	1		0.3501
# mantabb        	1		0.4177
# kelasss        	1		0.4177
# mendinganlah   	1		0.4177
# drpada         	1		0.4177
# salfok         	1		0.5568
# videonya       	1		0.5568
# angin          	1		0.6018
# segar          	1		0.6018
# ekspor         	1		0.2909
# dam            	1		0.2909
# pabrik²        	1		0.2909
# kulakan        	1		0.2909
# negeriotomatis 	1		0.2909
# nitip          	1		0.4127
# jejak          	1		0.4127
# barangnya      	1		0.4127
# pengampunan    	1		0.5117
# bntr           	1		0.3364
# salahnya       	1		0.3364
# dmana          	1		0.3364
# baraang        	1		0.3566
# 15jt           	1		0.3566
# brrti          	1		0.3645
# tangapi        	1		0.4834
# dasco          	1		0.4834
# disasar        	1		0.3962
# diinterupsi    	1		0.3962
# polusi         	1		0.2924

# %% [markdown]
# 10 teratas dan 10 terbawah dari hasil TF-IDF dan jumlah frekuensi

# %%
# Create DataFrames for top and bottom 10
top_10_df = pd.DataFrame(sorted_word_counts[:10], columns=['Word', 'Frequency'])
bottom_10_df = pd.DataFrame(sorted_word_counts[-10:], columns=['Word', 'Frequency'])

# Add TF-IDF to the DataFrames
top_10_df['TF-IDF'] = top_10_df['Word'].map(tfidf_values)
bottom_10_df['TF-IDF'] = bottom_10_df['Word'].map(tfidf_values)

# Display the top and bottom 10
print("Top 10 Words:")
display(top_10_df)

print("\nBottom 10 Words:")
display(bottom_10_df)
# Out:
# Top 10 Words:
#      Word  Frequency     TF-IDF
# 0  barang        459  64.495891
# 1   mewah        456  64.464366
# 2     pak        333  56.012869
# 3      di        273  33.724923
# 4     ppn        202  33.137209
# 5     apa        165  35.429281
# 6     itu        163  27.714269
# 7     dan        153  18.635672
# 8     ada        145  23.654039
# 9   pajak        143  22.430887
# Bottom 10 Words:
#           Word  Frequency    TF-IDF
# 0     salahnya          1  0.336372
# 1        dmana          1  0.336372
# 2      baraang          1  0.356642
# 3         15jt          1  0.356642
# 4        brrti          1  0.364522
# 5      tangapi          1  0.483406
# 6        dasco          1  0.483406
# 7      disasar          1  0.396204
# 8  diinterupsi          1  0.396204
# 9       polusi          1  0.292393

# %% [markdown]
# menghitung nilai mean  pada atribut setiap kelas dengan rumus

# %%
# Calculate the mean of each attribute for each class
def calculate_class_means(df, class_column, attribute_columns):
    """
    Calculates the mean of specified attributes for each class in a DataFrame.

    Args:
        df: The input DataFrame.
        class_column: The name of the column representing the class labels.
        attribute_columns: A list of column names representing the attributes.

    Returns:
        A DataFrame where each row represents a class and columns are the means of the attributes.
    """

    class_means = df.groupby(class_column)[attribute_columns].mean()
    return class_means

# Example usage: Assuming 'data' DataFrame and 'sentiment' column exist
# Replace 'sentiment' and the list of columns with your actual column names
attribute_columns = ['positive_score', 'negative_score'] # Example attributes
class_means_df = calculate_class_means(data, 'sentiment', attribute_columns)
class_means_df
# Out:
#            positive_score  negative_score
# sentiment
# Negatif          1.535627        3.378378
# Netral           0.635452        0.635452
# Positif          3.607313        1.352941

# %% [markdown]
# menghitung standar deviasi  pada atribut setiap kelas dengan rumus

# %%
import pandas as pd
import numpy as np

# Assuming 'data' DataFrame and 'sentiment' column exist as in the previous code
# and attribute_columns is defined as in the previous code

def calculate_class_std(df, class_column, attribute_columns):
    """
    Calculates the standard deviation of specified attributes for each class in a DataFrame.

    Args:
        df: The input DataFrame.
        class_column: The name of the column representing the class labels.
        attribute_columns: A list of column names representing the attributes.

    Returns:
        A DataFrame where each row represents a class and columns are the standard deviations of the attributes.
    """
    class_std = df.groupby(class_column)[attribute_columns].std()
    return class_std

# Example usage
attribute_columns = ['positive_score', 'negative_score']
class_std_df = calculate_class_std(data, 'sentiment', attribute_columns)
class_std_df
# Out:
#            positive_score  negative_score
# sentiment
# Negatif          2.177603        2.716366
# Netral           1.178058        1.178058
# Positif          3.540486        2.425858

# %% [markdown]
# menghitung probabilitas setiap kelas dengan rumus

# %%
import pandas as pd

# Assuming 'data' DataFrame and 'sentiment' column exist as in the previous code
# and attribute_columns is defined as in the previous code

def calculate_class_probabilities(df, class_column):
    """
    Calculates the probability of each class in a DataFrame.

    Args:
        df: The input DataFrame.
        class_column: The name of the column representing the class labels.

    Returns:
        A pandas Series representing the probability of each class.
    """
    class_counts = df[class_column].value_counts()
    class_probabilities = class_counts / len(df)
    return class_probabilities

# Example usage
class_probabilities = calculate_class_probabilities(data, 'sentiment')
class_probabilities
# Out:
# sentiment
# Positif    0.384945
# Netral     0.365973
# Negatif    0.249082
# Name: count, dtype: float64

# %% [markdown]
# Pelabelan Kelas Sentimen
# Penjelasan:
#
# Akurasi (Accuracy):
#
# Nilai akurasi adalah 0.75 atau 75%.
# Ini berarti model Anda secara benar memprediksi sentimen dari 75% data pengujian.
# Presisi (Precision):
#
# Negatif: Dari semua komentar yang diprediksi sebagai "Negatif", 69% benar-benar negatif.
# Netral: Dari semua komentar yang diprediksi sebagai "Netral", 74% benar-benar netral.
# Positif: Dari semua komentar yang diprediksi sebagai "Positif", 79% benar-benar positif.
# Recall (Recall):
#
# Negatif: Model berhasil mengidentifikasi 68% dari semua komentar negatif yang sebenarnya.
# Netral: Model berhasil mengidentifikasi 71% dari semua komentar netral yang sebenarnya.
# Positif: Model berhasil mengidentifikasi 83% dari semua komentar positif yang sebenarnya.
# F1-Score:
#
# F1-score adalah rata-rata harmonik dari presisi dan recall. Ini memberikan gambaran yang lebih seimbang tentang kinerja model, terutama ketika ada ketidakseimbangan kelas.
# Negatif: 0.68
# Netral: 0.73
# Positif: 0.81
# Support:
#
# Menunjukkan jumlah data aktual untuk setiap kelas sentimen dalam data pengujian.
# Negatif: 71 komentar
# Netral: 118 komentar
# Positif: 138 komentar
# macro avg & weighted avg
# macro avg menghitung rata-rata metrik (presisi, recall, F1-score) untuk setiap kelas tanpa mempertimbangkan jumlah data di setiap kelas.
# weighted avg menghitung rata-rata metrik untuk setiap kelas dengan mempertimbangkan jumlah data di setiap kelas. Lebih tepat digunakan jika ada ketidakseimbangan kelas.
# Kesimpulan:
#
# Secara keseluruhan, model Anda memiliki akurasi yang cukup baik (75%). Perhatikan bahwa model cenderung lebih baik dalam mengidentifikasi sentimen positif dibandingkan dengan negatif atau netral, dilihat dari skor recall dan F1-score yang lebih tinggi.

# %%
# Import necessary libraries (assuming they are already installed)
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'data' DataFrame is already loaded and processed as in the previous code

# Data preparation for sentiment analysis
# Assuming you have a 'sentiment' column in your DataFrame
# Replace 'sentiment' with the actual column name if it's different
# If the 'sentiment' column doesn't exist, create it and assign values
# For example, you can assign a default sentiment or load sentiment labels from another source
# Here's an example of creating a new 'sentiment' column and assigning a default value:

# Check if the 'sentiment' column exists
if 'sentiment' not in data.columns:

    data['sentiment'] = 'neutral'  # Initialize with 'neutral'
    # Instead of just labeling the first two rows, label more rows with 'positive' and 'negative'
    # For example, you can label a certain percentage of rows randomly:
    import random
    num_positive = int(len(data) * 0.90) # 25% positive
    num_negative = int(len(data) * 0.90) # 25% negative
    # secara acak memilih 25% data dan menetapkan label 'positive' dan 25% lainnya dengan label 'negative'.


    # Get random indices for positive and negative labels
    positive_indices = random.sample(range(len(data)), num_positive)
    negative_indices = random.sample(range(len(data)), num_negative)

    # Assign labels based on the random indices
    data.loc[positive_indices, 'sentiment'] = 'positive'
    data.loc[negative_indices, 'sentiment'] = 'negative'


data['sentiment'] = data['sentiment'].astype(str)  # Convert sentiment column to string type
data = data.dropna(subset=['Corrected_Comments', 'sentiment'])  # Drop rows with missing values in relevant columns


# Split data into training and testing sets
X = data['Corrected_Comments']  # Features (preprocessed comments)
y = data['sentiment']  # Target variable (sentiment labels)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)
#test_size=0.2: Menunjukkan bahwa 20% data akan digunakan untuk pengujian, dan 80% sisanya untuk pelatihan.
#random_state=42: Memastikan bahwa data dibagi dengan cara yang sama setiap kali kode dijalankan, membuat hasilnya dapat direproduksi.

# TF-IDF vectorization
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Model training (Logistic Regression)
model = LogisticRegression()
model.fit(X_train_vec, y_train)

# Model prediction
y_pred = model.predict(X_test_vec)

# Model evaluation
accuracy = accuracy_score(y_test, y_pred) #accuracy_score: Menghitung akurasi model dengan membandingkan label yang diprediksi (y_pred) dengan label sebenarnya (y_test).
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred)) #classification_report: Memberikan laporan yang lebih rinci termasuk presisi, recall, skor F1, dan dukungan untuk setiap kelas sentimen.


# Function to predict sentiment of new comments
def predict_sentiment(comment):
    comment_vec = vectorizer.transform([comment])
    sentiment = model.predict(comment_vec)[0]
    return sentiment

# Example usage:
new_comment = "Komentar baru untuk diuji"
predicted_sentiment = predict_sentiment(new_comment)
print(f"Sentiment of new comment '{new_comment}': {predicted_sentiment}")

results_df = pd.DataFrame({'Komentar': X_test, 'Sentimen Prediksi': y_pred})
print(results_df)

# You might need to adjust parameters, choose different models, or fine-tune the preprocessing steps for better performance
# Consider handling class imbalance or exploring other classification algorithms like Naive Bayes, SVM, or Random Forests.
# Out:
# Accuracy: 0.6475535168195719
#               precision    recall  f1-score   support
#
#      Negatif       0.71      0.40      0.51       321
#       Netral       0.69      0.64      0.66       485
#      Positif       0.60      0.81      0.69       502
#
#     accuracy                           0.65      1308
#    macro avg       0.67      0.62      0.62      1308
# weighted avg       0.66      0.65      0.64      1308
#
# Sentiment of new comment 'Komentar baru untuk diuji': Positif
#                                                Komentar Sentimen Prediksi
# 1360  rakyat kecil itu ga nongkrong2 di cafe di bar ...           Positif
# 1096  tetap was was ges... ini hnya agar meredakan p...           Positif
# 544   kita yang cuma gaji 3 jtan. ga akan bisa beli ...           Positif
# 506                                     jadinya ppnbm??            Netral
# 874                         minimal barang di harga 5jt           Positif
# ...                                                 ...               ...
# 658   meskipun rakyat kecil tidak kena dampak, tp se...           Negatif
# 1330  masalah nya masyarakat kecil skrg sering/suka ...           Positif
# 1019       anak wabah kecewa . anak wanah gagal nyinyir            Netral
# 1455                    bara mewa yang di maksud wowowo           Positif
# 959                                              hemmmm            Netral
#
# [1308 rows x 2 columns]

# %% [markdown]
# K- Fold Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
import numpy as np


# K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42) # 5 folds, shuffle data, set random state
accuracies = []
classification_reports = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    X_train_vec = vectorizer.fit_transform(X_train)
    X_test_vec = vectorizer.transform(X_test)

    model = LogisticRegression()
    model.fit(X_train_vec, y_train)

    y_pred = model.predict(X_test_vec)

    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

    report = classification_report(y_test, y_pred, output_dict=True)
    classification_reports.append(report)

# Calculate and print the average accuracy
avg_accuracy = np.mean(accuracies)
print(f"Average Accuracy across folds: {avg_accuracy}")

# Aggregate classification reports (you might want to average precision, recall, f1-score etc.)
# Example: Averaging precision for each class across folds
avg_precision_per_class = {}
for class_label in classification_reports[0]: # Assuming all folds have same labels
    if class_label in ('accuracy', 'macro avg', 'weighted avg'):
        continue # Skip these aggregate metrics
    avg_precision_per_class[class_label] = np.mean([fold_report[class_label]['precision'] for fold_report in classification_reports])
print("Average Precision per Class across folds:")
avg_precision_per_class
# Out:
# Average Accuracy across folds: 0.6940019887056528
# Average Precision per Class across folds:
# {'Negatif': 0.7252594594060688,
#  'Netral': 0.6668600699250387,
#  'Positif': 0.7074692770573777}

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming y_test and y_pred are already defined from your model prediction
cm = confusion_matrix(y_test, y_pred)

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# ... (your existing code for data loading, preprocessing, and train-test split)

# Model training (Random Forest)
model = RandomForestClassifier(random_state=42) # You can adjust hyperparameters here
model.fit(X_train_vec, y_train)

# Model prediction
y_pred = model.predict(X_test_vec)

# Model evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred))

# Function to predict sentiment of new comments
def predict_sentiment(comment):
    comment_vec = vectorizer.transform([comment])
    sentiment = model.predict(comment_vec)[0]
    return sentiment

# Example usage
new_comment = "Komentar baru untuk diuji"
predicted_sentiment = predict_sentiment(new_comment)
print(f"Sentiment of new comment '{new_comment}': {predicted_sentiment}")
# Out:
# Accuracy: 0.6748466257668712
#               precision    recall  f1-score   support
#
#      Negatif       0.65      0.52      0.58        86
#       Netral       0.68      0.71      0.69       113
#      Positif       0.68      0.75      0.71       127
#
#     accuracy                           0.67       326
#    macro avg       0.67      0.66      0.66       326
# weighted avg       0.67      0.67      0.67       326
#
# Sentiment of new comment 'Komentar baru untuk diuji': Netral
